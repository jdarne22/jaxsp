# %%
import jax
jax.config.update("jax_enable_x64", True)
import numpy as np
import jax.numpy as jnp

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.size'] = 10
mpl.rcParams['axes.grid'] = True
mpl.rcParams['axes.xmargin'] = 0
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['savefig.bbox'] = 'tight'

import jaxsp as jsp

from scipy import constants as const

import matplotlib.animation as animation
from IPython.display import HTML


import Stellar_sim_funcs as SSF
import importlib
importlib.reload(SSF)


from scipy.interpolate import interp1d

from collections import defaultdict

from jaxsp.constants import h, om, hbar, Msun, GN, c, m22

from collections import defaultdict

from scipy.interpolate import RegularGridInterpolator

# %%
u = SSF.return_u()

G = GN.value * (u.from_cm**3) / (u.from_g * u.from_s**2)

# %%
rho = jax.vmap(jsp.rho, in_axes=(0,None))

# rho is a function we can input array r and parameter values to get the density

# %%
cNFWtides_params = jnp.array([
    357964808.148399 * u.from_Msun, 
    25.690207, 
    0.407461, 
    0.012670 * u.from_Kpc, 
    1.857991 * u.from_Kpc, 
    3.729259
])
density_params = jsp.init_core_NFW_tides_params_from_sample(cNFWtides_params)
r99 = jsp.enclosing_radius(0.99, density_params) # radius that encloses 99% of mass
print(r99, "kpc")
density_params
# Out:
# 20.743367613524313 kpc
# core_NFW_tides_params:
# 	name=236146193804778771,
# 	M200=1118.7951678146808,
# 	c=25.690207,
# 	n=0.407461,
# 	rc=0.0005960840778498662,
# 	rt=0.0874126954923718,
# 	delta=3.729259,
#     Derived:
# 	rs=0.026822448297135815,
# 	g=0.4307070628318999,
# 	rho0=1987135.4034031027,

# %%
fig, ax = plt.subplots()
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.set_xscale("log")
ax.set_yscale("log")
r = jnp.logspace(jnp.log10(100 * u.from_pc), jnp.log10(r99), 200)
ax.plot(r * u.to_Kpc, rho(r, density_params) * u.to_Msun/u.to_Kpc**3)
ax.set_ylabel(r"$\rho \;\;\mathrm{[M_\odot\;kpc^{-3}]}$", fontsize = 18)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 18)
ax.set_title('DM density profile: NFW with cored center and tidal stripping effects', fontsize = 16)
plt.show()

# %%
potential = jax.vmap(jsp.potential, in_axes=(0,None))

# %%
rmin = .1 * u.from_pc
rmax = jsp.enclosing_radius(0.999, density_params)
N = 512
potential_params = jsp.init_potential_params(density_params, rmin, rmax, N) 
potential_params
# Out:
# potential_params:
# 	name=354410778964585829,
# 	density_params=236146193804778771,
# 	N=512,
# 	rmin=4.704688854379371e-06,
# 	rmax=488.53262239439164,

# %%
fig, ax = plt.subplots()
ax.set_xscale("log")
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
r = jnp.logspace(jnp.log10(rmin), jnp.log10(rmax), 200)
ax.plot(r * u.to_Kpc, potential(r, potential_params) * u.to_kms**2)
ax.set_ylabel(r"$V \;\;\mathrm{[km^2 \;s^{-2}]}$", fontsize = 15)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)

ax.set_title('Gravitational Potential Profile', fontsize = 20)
plt.show()

# %%
eval_library = jax.vmap(jax.vmap(jsp.eval_radial_eigenmode, in_axes=(None, 0)), in_axes=(0,None))

# %%
rmin = .1 * u.from_pc
rmax = jsp.enclosing_radius(0.99, density_params)
print(rmax * u.to_Kpc)
N = 1024
a = 1
b = 10
eigenstate_lib = jsp.init_eigenstate_library(potential_params, rmin, rmax, a, b, N)
eigenstate_lib
n = eigenstate_lib.radial_eigenmode_params.n 
l = eigenstate_lib.radial_eigenmode_params.l
print(max(l))
# print(len(n))
# Out:
# 440.90838428593
# 23

# %%
fig, ax = plt.subplots()
ax.set_xscale("log")
ax.set_yscale("log")
r = jnp.logspace(jnp.log10(20 * u.from_pc), jnp.log10(rmax), 1000)
R_j_r = eval_library(r, eigenstate_lib.radial_eigenmode_params)
ax.set_title('Radial Eigenmodes', fontsize = 20)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
ax.set_ylabel(r"$R_{j}(r)^2 \;\;\mathrm{[kpc^{-1}]}$", fontsize = 15)
ax.plot(r * u.to_Kpc, R_j_r**2, lw=0.5)
ax.set_ylim([1e-15, 1e5])
plt.show()

# %%
rho_psi = jax.vmap(jsp.rho_psi, in_axes=(0,None,None))

# %%
tol = 1e-7
rmin = 20 * u.from_pc
rmax = jsp.enclosing_radius(0.99, density_params)
wavefunction_params = jsp.init_wavefunction_params(eigenstate_lib, density_params, rmin, rmax, tol)
wavefunction_params
# Out:
# wavefunction_params:
# 	name=321443324063497960,
# 	eigenstate_library=720428951175803208,
# 	density_params=236146193804778771,
# 	aj_2=[3.720980066807119e-29, 0.6378987955514653],
# 	total_mass=716.415885628137,
# 	r_min=0.000940937770875874,
# 	r_max=20.743367613524313,
# 	distance=0.03034410943743295,

# %%
fig, ax = plt.subplots()
ax.set_xscale("log")
ax.set_yscale("log")

r = jnp.logspace(jnp.log10(rmin), jnp.log10(rmax), 1000)
ax.plot(r * u.to_Kpc, rho(r, density_params) * u.to_Msun / u.to_Kpc**3, label='cNFWtides density')
ax.plot(r * u.to_Kpc, rho_psi(r, wavefunction_params, eigenstate_lib) * u.to_Msun / u.to_Kpc**3, label='wavefunction reconstructed density', ls='--')
ax.set_ylabel(r"$\rho \;\;\mathrm{[M_\odot\;kpc^{-3}]}$", fontsize = 15)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# # With Time Evolution

# %%
r = np.logspace(np.log10(rmin), np.log10(rmax), 1000)

rho_psi_vals = rho_psi(r, wavefunction_params, eigenstate_lib)

Phi_psi = SSF.Obtain_pot(rmin, rmax, rho_psi_vals, r)

fig, ax = plt.subplots()
ax.set_xscale("log")
ax.plot(r * u.to_Kpc, Phi_psi * u.to_kms**2, label='wavefunction potential at time t = 0', lw=2, ls='--')
ax.plot(r * u.to_Kpc, potential(r, potential_params) * u.to_kms**2, label='input potential', lw=2)
ax.set_ylabel(r"$V \;\;\mathrm{[km^2 \;s^{-2}]}$", fontsize = 15)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

m_dm = 1 * 10**(-22) * 1.6 * 10**(-19) / (3 * 10**(8))**2  # mass of dark matter particle in units of 10^-22 eV

h_bar = hbar.value * 1e-7

dt_De_B = h_bar / (m_dm * 6000) * u.from_s # in seconds

print(dt_De_B * u.to_Gyr)
# Out:
# 3132.937568921591

# %%
r_orbit = 0.19 * u.from_Kpc

init_pos = np.array([r_orbit, 0, 0]) #Starting as position (r_vir, 0, 0) = (x, y, z)

orbit = plt.Circle((0, 0), r_orbit * u.to_Kpc, color='black', fill=False, linestyle='--', label='Star Orbit')
fig, ax = plt.subplots() 

ax.add_patch(orbit)
ax.set_xlim(-0.5 , 0.5)
ax.set_ylim(-0.5 , 0.5)

ax.set_aspect('equal', adjustable='box')

plt.scatter(r_orbit * u.to_Kpc, 0, color='red', label='Star Initial Position')
plt.scatter(0, 0, color='blue', label='Halo Center', marker='x')

ax.set_xlabel(r"$x \;\;\mathrm{[kpc]}$", fontsize = 15)
ax.set_ylabel(r"$y \;\;\mathrm{[kpc]}$", fontsize = 15)
plt.show()

# %%
importlib.reload(SSF)


total_evolve_time = 5 * u.from_Gyr
num_steps = 10000
dt = total_evolve_time / num_steps

rho_rtp, rho_psi_time_stepped, radial_eigen_functions, radial_eigen_function_time_stepped, theta, phi, dtheta, dphi, Y_lms = SSF.Calculating_rho_from_psi_3d(r, eigenstate_lib, wavefunction_params, dt, eval_library)

plt.plot(r * u.to_Kpc, radial_eigen_functions**2, lw=0.5)
plt.xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize=15)
plt.ylabel(r"$R_{j}(r)^2 \;\;\mathrm{[kpc^{-1}]}$", fontsize=15)
plt.title('Wavefunctions at t = 0')
plt.xscale("log")
plt.yscale("log")
plt.ylim([1e-15, 1e5])
plt.xlim([rmin * u.to_Kpc, rmax * u.to_Kpc])
plt.show()

plt.plot(r * u.to_Kpc, radial_eigen_function_time_stepped**2, lw=0.5)
plt.title('Wavefunctions at t = dt')
plt.xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize=15)
plt.ylabel(r"$R_{j}(r)^2 \;\;\mathrm{[kpc^{-1}]}$", fontsize=15)
plt.xscale("log")
plt.yscale("log")
plt.ylim([1e-15, 1e5])
plt.show()


fig, ax = plt.subplots()
ax.set_xscale("log")
ax.set_yscale("log")

rho0 = rho_psi(r, wavefunction_params, eigenstate_lib)

ax.plot(r * u.to_Kpc,rho0 * u.to_Msun / u.to_Kpc**3,label='wavefunction reconstructed density at time t = 0',ls='--')
ax.plot(r * u.to_Kpc,rho_psi_time_stepped * u.to_Msun / u.to_Kpc**3,label='wavefunction reconstructed density at time t = dt',ls='-.')
ax.set_ylabel(r"$\rho \;\;\mathrm{[M_\odot\;kpc^{-3}]}$", fontsize=15)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize=15)
plt.legend(fontsize=14)
plt.show()

fraction = rho_psi_time_stepped / rho0
plt.plot(r * u.to_Kpc, fraction)
plt.xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize=15)
plt.ylabel(r"$\frac{\rho_{\psi}(t=dt)}{\rho_{\psi}(t=0)}$", fontsize=15)
plt.axhline(1, color='red', ls='--')
plt.xscale("log")
plt.yscale("log")
plt.show()
# Out:
# (1000, 290)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       5 num_steps = 10000
#       6 dt = total_evolve_time / num_steps
# ----> 8 rho_rtp, rho_psi_time_stepped, radial_eigen_functions, radial_eigen_function_time_stepped, theta, phi, dtheta, dphi, Y_lms = SSF.Calculating_rho_from_psi_3d(r, eigenstate_lib, wavefunction_params, dt, eval_library)
#      10 plt.plot(r * u.to_Kpc, radial_eigen_functions**2, lw=0.5)
#      11 plt.xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize=15)
#
# File ~/PhD_year_1/jaxsp/Adding_stellar_masses/Stellar_sim_funcs.py:551, in Calculating_rho_from_psi_3d(r, eigenstate_lib, wavefunction_params, dt, eval_library)
#     549 Y_list = []
#     550 for ell, m in zip(lm_l, lm_m):
# --> 551     Y_lm_mode = sph_harm(m, ell, Phi, Theta)  # (n_theta, n_phi), complex
#     552     Y_list.append(Y_lm_mode)
#     554 Y_lm = jnp.stack(Y_list, axis=0)  # (Nmodes, n_theta, n_phi), complex
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8, 6))
i = 300
plt.imshow(rho_rtp[i,:,:], extent=(0, 2 * np.pi, 0, np.pi), aspect='auto')
plt.colorbar()
plt.xlabel(r'$\phi$')
plt.ylabel(r'$\theta$')
plt.title('Density Distribution at r = %.2f kpc' % (r[i] * u.to_Kpc))
plt.show()

# %%
importlib.reload(SSF)

lm_pairs = SSF.precompute_lm_pairs(int(l.max()) + 1)
G = GN.value * (u.from_cm**3) / (u.from_g * u.from_s**2)


Phi_rtp, Phi_r_dt = SSF.Calculating_Phi_from_rho_in_3d_optimized(l, rho_rtp, r, dtheta, dphi, theta, phi, lm_pairs, G)


Phi_rtp, r_vals = SSF.Calculating_Phi_from_rho_in_3d_optimized_at_r_orbit(l, rho_rtp, r, r_orbit, lm_pairs, G)

Phi_rtp = Phi_rtp.real

# %%
fig, ax = plt.subplots()
ax.set_xscale("log")
ax.plot(r * u.to_Kpc, Phi_r_dt * u.to_kms**2, label='wavefunction potential at time t = dt from spherical harmonics', lw=2, ls='--')
ax.plot(r * u.to_Kpc, potential(r, potential_params) * u.to_kms**2, label='input potential', lw=2)
ax.plot(r * u.to_Kpc, Phi_psi * u.to_kms**2, label='wavefunction potential at time t = 0', lw=2, ls=':')
ax.axvline(r_orbit * u.to_Kpc, color='red', ls=':', label='Star Initial Orbit Radius')
ax.set_ylabel(r"$V \;\;\mathrm{[km^2 \;s^{-2}]}$", fontsize = 15)
ax.set_xlabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# # Create new u.to_kpc as need to only multiply r term by it

# %%
to_kpc = jnp.array([u.to_Kpc, 1, 1])

# %% [markdown]
# ## $\vec{a} = -\vec{\nabla} V$
# ## $\vec{a} = -(\frac{dV}{dr}\vec{\hat{r}} + \frac{1}{r}\frac{dV}{d\theta}\vec{\hat{\theta}} + \frac{1}{r\sin{\theta}}\frac{dV}{d\phi}\vec{\hat{\phi}})$

# %%
print(r_vals * u.to_Kpc)

import importlib
importlib.reload(SSF)

init_pos_sph = SSF.Cartesian_to_sph(init_pos[0], init_pos[1], init_pos[2])

acc_vec = SSF.Acc_from_pot_3d(Phi_rtp, r_vals, theta, phi) # (3, 3, n_theta, n_phi) = (dim, Nr, n_theta, n_phi)

# Reshape to (r, theta, phi, 3) for a single interpolator
data_transposed = np.moveaxis(acc_vec, 0, -1)  # shape (3, 24, 47, 3)

interp = RegularGridInterpolator(
    (r_vals, theta, phi),
    data_transposed,
    method='linear'
)

print("Star spherical position: ", init_pos_sph * to_kpc)
result = interp(list(init_pos_sph))

print(result[0])
# Out:
# [0.17209894 0.17383045 0.17557939 0.17734592 0.17913022 0.18093247
#  0.18275286 0.18459157 0.18644877 0.18832466 0.19021942 0.19213325
#  0.19406633 0.19601886 0.19799103 0.19998305 0.20199511 0.20402741
#  0.20608016 0.20815356 0.21024783]
# Star spherical position:  [0.19       1.57079633 0.        ]
# [-6.31998226e+02 -6.13205558e-01  1.88361060e+00]

# %% [markdown]
# # Time dependent simulation run
#
# ## Leapfrog Integration

# %%
# importlib.reload(SSF)

# total_evolve_time = 5 * u.from_Gyr
# num_steps = 500
# dt = total_evolve_time / num_steps
# num_steps = 500

# r = np.logspace(np.log10(rmin), np.log10(rmax), 1000)

# r_orbit = 0.19 * u.from_Kpc

# init_pos = np.array([r_orbit, 0, 0]) #Starting as position (r_vir, 0, 0) = (x, y, z)

# print("Star initial position (kpc): ", init_pos * u.to_Kpc)

# eigen_energies = eigenstate_lib.radial_eigenmode_params.E  # shape (Nj,)
# total_mass = wavefunction_params.total_mass
# R_j_r = eval_library(r, eigenstate_lib.radial_eigenmode_params)
# l = eigenstate_lib.radial_eigenmode_params.l

# aj_2 = wavefunction_params.aj_2        # shape (Nj,)
# rand_phase = jax.random.uniform(jax.random.PRNGKey(0), shape=aj_2.shape, minval=0.0, maxval=2 * jnp.pi,)
# aj = np.sqrt(aj_2) * np.exp(1j * rand_phase)  # shape (Nj,)


# stellar_v_disp, total_avg_r, r_values, velocities = SSF.Simulate_time_dep_3d(r_orbit, init_pos, dt, num_steps, r, eigen_energies, l, R_j_r, aj, total_mass, Phi_psi, Y_lms)

# %%
# fig, ax = plt.subplots()


# ax.plot(np.arange(num_steps) * dt * u.to_Gyr, jnp.array(total_avg_r) * u.to_Kpc, label='Average Radial Distance from Halo Center', ls='--')
# #ax.plot(np.arange(num_steps) * dt * u.to_Gyr, jnp.array(r_values) * u.to_Kpc, label='Star Radial Distance from Halo Center', ls='-')
# ax.axhline(r_orbit * u.to_Kpc, color='red', ls=':', label='Initial Orbit Radius')
# ax.set_ylabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
# ax.set_xlabel(r"Gyr", fontsize = 15)
# plt.legend(fontsize = 14)
# plt.show()

# fig, ax = plt.subplots()

# stellar_v_disp = jnp.array(stellar_v_disp)


# ax.plot(np.arange(num_steps) * dt * u.to_Gyr, stellar_v_disp * u.to_kms, label='Stellar Velocity Dispersion')
# plt.yscale('log')
# ax.set_ylabel(r"$\sigma_v \;\;\mathrm{[km/s]}$", fontsize = 15)
# ax.set_xlabel(r"Gyr", fontsize = 15)
# plt.legend(fontsize = 14)
# plt.show()

# %% [markdown]
# ## Hanno Reins

# %%
importlib.reload(SSF)

total_evolve_time = 5 * u.from_Gyr
num_steps = 1000
dt = total_evolve_time / num_steps
num_steps = 1000

r = np.logspace(np.log10(rmin), np.log10(rmax), 1000)

r_orbit = 0.19 * u.from_Kpc

init_pos = np.array([r_orbit, 0, 0]) #Starting as position (r_vir, 0, 0) = (x, y, z)

print("Star initial position (kpc): ", init_pos * u.to_Kpc)

eigen_energies = eigenstate_lib.radial_eigenmode_params.E  # shape (Nj,)
total_mass = wavefunction_params.total_mass
R_j_r = eval_library(r, eigenstate_lib.radial_eigenmode_params)
l = eigenstate_lib.radial_eigenmode_params.l

aj_2 = wavefunction_params.aj_2        # shape (Nj,)
rand_phase = jax.random.uniform(jax.random.PRNGKey(0), shape=aj_2.shape, minval=0.0, maxval=2 * jnp.pi,)
aj = np.sqrt(aj_2) * np.exp(1j * rand_phase)  # shape (Nj,)


stellar_v_disp, total_avg_r, r_values, velocities = SSF.Simulate_time_dep_3d_Hanno_Reins(r_orbit, init_pos, dt, num_steps, r, eigen_energies, l, R_j_r, aj, total_mass, Phi_psi, Y_lms, print_every = 10)
# Out:
# Star initial position (kpc):  [0.19 0.   0.  ]
# Initialization time (s):  0.31020402908325195
# Star position (r, theta, phi) in kpc:  [0.19000067 1.49794533 0.        ]
# Time for wavefunction update (s):  0.7323462963104248
# Time taken for forward SHT (s):  0.1286313533782959
# Time taken for integration at r_orbit (s):  1.7787530422210693
# Time taken for inverse SHT at r_orbit (s):  1.4754104614257812
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.9692163467407227
# Time for updating particle position and interpolating acc (s):  0.6072802543640137
# Star position (r, theta, phi) in kpc:  [1.90082242e-01 1.42499506e+00 3.16474064e-06]
# Time for wavefunction update (s):  0.042318105697631836
# Time taken for forward SHT (s):  0.1292414665222168
# Time taken for integration at r_orbit (s):  0.03495144844055176
# Time taken for inverse SHT at r_orbit (s):  0.0019919872283935547
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028891563415527344
# Time for updating particle position and interpolating acc (s):  0.17646479606628418
# Star position (r, theta, phi) in kpc:  [1.90262282e-01 1.35215117e+00 1.27242697e-05]
# Time for wavefunction update (s):  0.04598832130432129
# Time taken for forward SHT (s):  0.11554908752441406
# Time taken for integration at r_orbit (s):  0.03396344184875488
# Time taken for inverse SHT at r_orbit (s):  0.001995563507080078
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002866029739379883
# Time for updating particle position and interpolating acc (s):  0.175750732421875
# Star position (r, theta, phi) in kpc:  [1.90118230e-01 1.27936193e+00 2.82471542e-05]
# Time for wavefunction update (s):  0.0415501594543457
# Time taken for forward SHT (s):  0.11614274978637695
# Time taken for integration at r_orbit (s):  0.03450584411621094
# Time taken for inverse SHT at r_orbit (s):  0.0020020008087158203
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028486251831054688
# Time for updating particle position and interpolating acc (s):  0.17325162887573242
# Star position (r, theta, phi) in kpc:  [1.89933412e-01 1.20636868e+00 5.13139507e-05]
# Time for wavefunction update (s):  0.04430961608886719
# Time taken for forward SHT (s):  0.11589789390563965
# Time taken for integration at r_orbit (s):  0.0341949462890625
# Time taken for inverse SHT at r_orbit (s):  0.0020287036895751953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028874874114990234
# Time for updating particle position and interpolating acc (s):  0.17316007614135742
# Star position (r, theta, phi) in kpc:  [1.89957200e-01 1.13336370e+00 8.69422649e-05]
# Time for wavefunction update (s):  0.04243898391723633
# Time taken for forward SHT (s):  0.11619114875793457
# Time taken for integration at r_orbit (s):  0.03405284881591797
# Time taken for inverse SHT at r_orbit (s):  0.001976490020751953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002833843231201172
# Time for updating particle position and interpolating acc (s):  0.1766643524169922
# Star position (r, theta, phi) in kpc:  [1.90268072e-01 1.06042189e+00 1.35671769e-04]
# Time for wavefunction update (s):  0.03980755805969238
# Time taken for forward SHT (s):  0.11600875854492188
# Time taken for integration at r_orbit (s):  0.03386545181274414
# Time taken for inverse SHT at r_orbit (s):  0.001963376998901367
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002857685089111328
# Time for updating particle position and interpolating acc (s):  0.17688274383544922
# Star position (r, theta, phi) in kpc:  [1.90834370e-01 9.87872830e-01 2.01950185e-04]
# Time for wavefunction update (s):  0.03829455375671387
# Time taken for forward SHT (s):  0.11605334281921387
# Time taken for integration at r_orbit (s):  0.03412508964538574
# Time taken for inverse SHT at r_orbit (s):  0.0019788742065429688
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028312206268310547
# Time for updating particle position and interpolating acc (s):  0.17621564865112305
# Star position (r, theta, phi) in kpc:  [1.91071941e-01 9.15625252e-01 2.78580130e-04]
# Time for wavefunction update (s):  0.04251456260681152
# Time taken for forward SHT (s):  0.11592745780944824
# Time taken for integration at r_orbit (s):  0.03376913070678711
# Time taken for inverse SHT at r_orbit (s):  0.001990795135498047
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028531551361083984
# Time for updating particle position and interpolating acc (s):  0.1738119125366211
# Step 10/1000
# Star position (r, theta, phi) in kpc:  [1.91088273e-01 8.43436140e-01 3.42833334e-04]
# Time for wavefunction update (s):  0.04215717315673828
# Time taken for forward SHT (s):  0.11592602729797363
# Time taken for integration at r_orbit (s):  0.03405618667602539
# Time taken for inverse SHT at r_orbit (s):  0.0019659996032714844
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028367042541503906
# Time for updating particle position and interpolating acc (s):  0.17207813262939453
# Star position (r, theta, phi) in kpc:  [1.90853874e-01 7.71190203e-01 3.96172484e-04]
# Time for wavefunction update (s):  0.04738783836364746
# Time taken for forward SHT (s):  0.11571121215820312
# Time taken for integration at r_orbit (s):  0.033757925033569336
# Time taken for inverse SHT at r_orbit (s):  0.001973867416381836
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028412342071533203
# Time for updating particle position and interpolating acc (s):  0.17508244514465332
# Star position (r, theta, phi) in kpc:  [1.90422662e-01 6.98659224e-01 4.39303594e-04]
# Time for wavefunction update (s):  0.03834104537963867
# Time taken for forward SHT (s):  0.11603546142578125
# Time taken for integration at r_orbit (s):  0.03424263000488281
# Time taken for inverse SHT at r_orbit (s):  0.0019609928131103516
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028400421142578125
# Time for updating particle position and interpolating acc (s):  0.17329025268554688
# Star position (r, theta, phi) in kpc:  [1.90341611e-01 6.25896036e-01 4.63545708e-04]
# Time for wavefunction update (s):  0.04826068878173828
# Time taken for forward SHT (s):  0.11579465866088867
# Time taken for integration at r_orbit (s):  0.03374361991882324
# Time taken for inverse SHT at r_orbit (s):  0.001961946487426758
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028269290924072266
# Time for updating particle position and interpolating acc (s):  0.17401885986328125
# Star position (r, theta, phi) in kpc:  [1.90421862e-01 5.53191228e-01 4.66801664e-04]
# Time for wavefunction update (s):  0.03850436210632324
# Time taken for forward SHT (s):  0.11597061157226562
# Time taken for integration at r_orbit (s):  0.034097909927368164
# Time taken for inverse SHT at r_orbit (s):  0.0019464492797851562
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002838611602783203
# Time for updating particle position and interpolating acc (s):  0.17140483856201172
# Star position (r, theta, phi) in kpc:  [1.90553617e-01 4.80521148e-01 4.39906089e-04]
# Time for wavefunction update (s):  0.04686260223388672
# Time taken for forward SHT (s):  0.11593461036682129
# Time taken for integration at r_orbit (s):  0.03386354446411133
# Time taken for inverse SHT at r_orbit (s):  0.0019931793212890625
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002835512161254883
# Time for updating particle position and interpolating acc (s):  0.17678332328796387
# Star position (r, theta, phi) in kpc:  [1.90774833e-01 4.08029320e-01 3.61702060e-04]
# Time for wavefunction update (s):  0.03885054588317871
# Time taken for forward SHT (s):  0.11607718467712402
# Time taken for integration at r_orbit (s):  0.03395962715148926
# Time taken for inverse SHT at r_orbit (s):  0.001977682113647461
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028460025787353516
# Time for updating particle position and interpolating acc (s):  0.17177700996398926
# Star position (r, theta, phi) in kpc:  [1.90772826e-01 3.35621240e-01 2.37081919e-04]
# Time for wavefunction update (s):  0.04419517517089844
# Time taken for forward SHT (s):  0.11568045616149902
# Time taken for integration at r_orbit (s):  0.033728599548339844
# Time taken for inverse SHT at r_orbit (s):  0.0019350051879882812
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028076171875
# Time for updating particle position and interpolating acc (s):  0.16996002197265625
# Star position (r, theta, phi) in kpc:  [1.90909549e-01 2.63218664e-01 5.36124847e-05]
# Time for wavefunction update (s):  0.0413968563079834
# Time taken for forward SHT (s):  0.11588478088378906
# Time taken for integration at r_orbit (s):  0.03411364555358887
# Time taken for inverse SHT at r_orbit (s):  0.001959562301635742
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028290748596191406
# Time for updating particle position and interpolating acc (s):  0.17250728607177734
# Star position (r, theta, phi) in kpc:  [0.19101421 0.19097016 6.28289647]
# Time for wavefunction update (s):  0.04487490653991699
# Time taken for forward SHT (s):  0.11589241027832031
# Time taken for integration at r_orbit (s):  0.03376317024230957
# Time taken for inverse SHT at r_orbit (s):  0.0019500255584716797
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028481483459472656
# Time for updating particle position and interpolating acc (s):  0.17794251441955566
# Step 20/1000
# Star position (r, theta, phi) in kpc:  [0.1906741  0.11861607 6.28208415]
# Time for wavefunction update (s):  0.039228200912475586
# Time taken for forward SHT (s):  0.11594533920288086
# Time taken for integration at r_orbit (s):  0.03421902656555176
# Time taken for inverse SHT at r_orbit (s):  0.001963376998901367
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028264522552490234
# Time for updating particle position and interpolating acc (s):  0.1420741081237793
# Star position (r, theta, phi) in kpc:  [0.19040027 0.04597914 6.27865709]
# Time for wavefunction update (s):  0.039629459381103516
# Time taken for forward SHT (s):  0.11570334434509277
# Time taken for integration at r_orbit (s):  0.03365898132324219
# Time taken for inverse SHT at r_orbit (s):  0.0019774436950683594
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002820253372192383
# Time for updating particle position and interpolating acc (s):  0.17609786987304688
# Star position (r, theta, phi) in kpc:  [0.19018326 0.02679572 3.15226314]
# Time for wavefunction update (s):  0.03885984420776367
# Time taken for forward SHT (s):  0.11605215072631836
# Time taken for integration at r_orbit (s):  0.034010887145996094
# Time taken for inverse SHT at r_orbit (s):  0.0019614696502685547
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028166770935058594
# Time for updating particle position and interpolating acc (s):  0.17367172241210938
# Star position (r, theta, phi) in kpc:  [0.18949119 0.09990022 3.1452101 ]
# Time for wavefunction update (s):  0.04526662826538086
# Time taken for forward SHT (s):  0.1158609390258789
# Time taken for integration at r_orbit (s):  0.03368568420410156
# Time taken for inverse SHT at r_orbit (s):  0.0019600391387939453
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028243064880371094
# Time for updating particle position and interpolating acc (s):  0.17586755752563477
# Star position (r, theta, phi) in kpc:  [0.18849523 0.17369865 3.14409753]
# Time for wavefunction update (s):  0.03928828239440918
# Time taken for forward SHT (s):  0.11592769622802734
# Time taken for integration at r_orbit (s):  1.2732374668121338
# Time taken for inverse SHT at r_orbit (s):  0.0021262168884277344
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029480457305908203
# Time for updating particle position and interpolating acc (s):  0.17928647994995117
# Star position (r, theta, phi) in kpc:  [0.18733563 0.24832918 3.14363968]
# Time for wavefunction update (s):  0.03938937187194824
# Time taken for forward SHT (s):  0.1287689208984375
# Time taken for integration at r_orbit (s):  1.3389825820922852
# Time taken for inverse SHT at r_orbit (s):  0.002074003219604492
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029425621032714844
# Time for updating particle position and interpolating acc (s):  0.18068218231201172
# Star position (r, theta, phi) in kpc:  [0.18616305 0.3239365  3.14335859]
# Time for wavefunction update (s):  0.039575815200805664
# Time taken for forward SHT (s):  0.11584877967834473
# Time taken for integration at r_orbit (s):  0.03425884246826172
# Time taken for inverse SHT at r_orbit (s):  0.0019884109497070312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029325485229492188
# Time for updating particle position and interpolating acc (s):  0.17898774147033691
# Star position (r, theta, phi) in kpc:  [0.1853489  0.40036085 3.14318695]
# Time for wavefunction update (s):  0.04616498947143555
# Time taken for forward SHT (s):  0.11571717262268066
# Time taken for integration at r_orbit (s):  1.286637783050537
# Time taken for inverse SHT at r_orbit (s):  0.0020716190338134766
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002941608428955078
# Time for updating particle position and interpolating acc (s):  0.18095922470092773
# Star position (r, theta, phi) in kpc:  [0.18472905 0.4773481  3.14310809]
# Time for wavefunction update (s):  0.03555464744567871
# Time taken for forward SHT (s):  0.11592221260070801
# Time taken for integration at r_orbit (s):  0.034476280212402344
# Time taken for inverse SHT at r_orbit (s):  0.0020134449005126953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029244422912597656
# Time for updating particle position and interpolating acc (s):  0.17999863624572754
# Star position (r, theta, phi) in kpc:  [0.18389396 0.55492537 3.14307455]
# Time for wavefunction update (s):  0.0455479621887207
# Time taken for forward SHT (s):  0.12860107421875
# Time taken for integration at r_orbit (s):  0.03466224670410156
# Time taken for inverse SHT at r_orbit (s):  0.0020537376403808594
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028727054595947266
# Time for updating particle position and interpolating acc (s):  0.17711114883422852
# Step 30/1000
# Star position (r, theta, phi) in kpc:  [0.18301321 0.63328225 3.14306709]
# Time for wavefunction update (s):  0.038396358489990234
# Time taken for forward SHT (s):  0.11612510681152344
# Time taken for integration at r_orbit (s):  1.2934000492095947
# Time taken for inverse SHT at r_orbit (s):  0.0020334720611572266
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002958059310913086
# Time for updating particle position and interpolating acc (s):  0.17723631858825684
# Star position (r, theta, phi) in kpc:  [0.18233063 0.71230128 3.14307397]
# Time for wavefunction update (s):  0.038889169692993164
# Time taken for forward SHT (s):  0.12871646881103516
# Time taken for integration at r_orbit (s):  0.03478693962097168
# Time taken for inverse SHT at r_orbit (s):  0.0020380020141601562
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002890348434448242
# Time for updating particle position and interpolating acc (s):  0.18320107460021973
# Star position (r, theta, phi) in kpc:  [0.18165462 0.79190055 3.14308523]
# Time for wavefunction update (s):  0.03833603858947754
# Time taken for forward SHT (s):  0.11609697341918945
# Time taken for integration at r_orbit (s):  1.373687744140625
# Time taken for inverse SHT at r_orbit (s):  0.002092123031616211
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029799938201904297
# Time for updating particle position and interpolating acc (s):  0.18007516860961914
# Star position (r, theta, phi) in kpc:  [0.18128119 0.87201575 3.14310914]
# Time for wavefunction update (s):  0.03890180587768555
# Time taken for forward SHT (s):  0.11598038673400879
# Time taken for integration at r_orbit (s):  0.0344541072845459
# Time taken for inverse SHT at r_orbit (s):  0.002002239227294922
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029113292694091797
# Time for updating particle position and interpolating acc (s):  0.1815793514251709
# Star position (r, theta, phi) in kpc:  [0.18118622 0.95229066 3.14313321]
# Time for wavefunction update (s):  0.04460573196411133
# Time taken for forward SHT (s):  0.11571788787841797
# Time taken for integration at r_orbit (s):  0.03448605537414551
# Time taken for inverse SHT at r_orbit (s):  0.001987457275390625
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002882719039916992
# Time for updating particle position and interpolating acc (s):  0.18311142921447754
# Star position (r, theta, phi) in kpc:  [0.18107998 1.03268649 3.14313542]
# Time for wavefunction update (s):  0.03849148750305176
# Time taken for forward SHT (s):  0.11600446701049805
# Time taken for integration at r_orbit (s):  0.034970998764038086
# Time taken for inverse SHT at r_orbit (s):  0.0020067691802978516
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002891063690185547
# Time for updating particle position and interpolating acc (s):  0.178558349609375
# Star position (r, theta, phi) in kpc:  [0.1814912  1.11300833 3.14312301]
# Time for wavefunction update (s):  0.037952423095703125
# Time taken for forward SHT (s):  0.11589741706848145
# Time taken for integration at r_orbit (s):  0.0346674919128418
# Time taken for inverse SHT at r_orbit (s):  0.0019960403442382812
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002899169921875
# Time for updating particle position and interpolating acc (s):  0.17781376838684082
# Star position (r, theta, phi) in kpc:  [0.18244736 1.19266924 3.14310408]
# Time for wavefunction update (s):  0.04505276679992676
# Time taken for forward SHT (s):  0.11554217338562012
# Time taken for integration at r_orbit (s):  0.038564443588256836
# Time taken for inverse SHT at r_orbit (s):  0.002019643783569336
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002867460250854492
# Time for updating particle position and interpolating acc (s):  0.17808985710144043
# Star position (r, theta, phi) in kpc:  [0.18392541 1.27133017 3.14308683]
# Time for wavefunction update (s):  0.037810325622558594
# Time taken for forward SHT (s):  0.11609959602355957
# Time taken for integration at r_orbit (s):  0.03519725799560547
# Time taken for inverse SHT at r_orbit (s):  0.0019850730895996094
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002859830856323242
# Time for updating particle position and interpolating acc (s):  0.17757773399353027
# Star position (r, theta, phi) in kpc:  [0.18598577 1.34845813 3.14307033]
# Time for wavefunction update (s):  0.038829803466796875
# Time taken for forward SHT (s):  0.11606192588806152
# Time taken for integration at r_orbit (s):  0.03436684608459473
# Time taken for inverse SHT at r_orbit (s):  0.001980304718017578
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002876758575439453
# Time for updating particle position and interpolating acc (s):  0.1884169578552246
# Step 40/1000
# Star position (r, theta, phi) in kpc:  [0.1878269  1.42392237 3.14303109]
# Time for wavefunction update (s):  0.04687643051147461
# Time taken for forward SHT (s):  0.11623287200927734
# Time taken for integration at r_orbit (s):  0.03575897216796875
# Time taken for inverse SHT at r_orbit (s):  0.002048492431640625
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002871274948120117
# Time for updating particle position and interpolating acc (s):  0.18894195556640625
# Star position (r, theta, phi) in kpc:  [0.18957108 1.49803928 3.14297506]
# Time for wavefunction update (s):  0.03955268859863281
# Time taken for forward SHT (s):  0.11596465110778809
# Time taken for integration at r_orbit (s):  0.03766965866088867
# Time taken for inverse SHT at r_orbit (s):  0.002432584762573242
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0034933090209960938
# Time for updating particle position and interpolating acc (s):  0.18784117698669434
# Star position (r, theta, phi) in kpc:  [0.19175001 1.57062167 3.14292682]
# Time for wavefunction update (s):  0.0381464958190918
# Time taken for forward SHT (s):  0.11623644828796387
# Time taken for integration at r_orbit (s):  1.327772855758667
# Time taken for inverse SHT at r_orbit (s):  0.0031180381774902344
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.004047393798828125
# Time for updating particle position and interpolating acc (s):  0.1814587116241455
# Star position (r, theta, phi) in kpc:  [0.1939981  1.64150717 3.14287592]
# Time for wavefunction update (s):  0.038990020751953125
# Time taken for forward SHT (s):  0.11627054214477539
# Time taken for integration at r_orbit (s):  1.446099042892456
# Time taken for inverse SHT at r_orbit (s):  0.002089262008666992
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002955913543701172
# Time for updating particle position and interpolating acc (s):  0.17793631553649902
# Star position (r, theta, phi) in kpc:  [0.19594364 1.71085617 3.14282636]
# Time for wavefunction update (s):  0.04115748405456543
# Time taken for forward SHT (s):  0.1175069808959961
# Time taken for integration at r_orbit (s):  1.353158950805664
# Time taken for inverse SHT at r_orbit (s):  0.002138853073120117
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.003010272979736328
# Time for updating particle position and interpolating acc (s):  0.17972660064697266
# Star position (r, theta, phi) in kpc:  [0.19753587 1.77897472 3.14278968]
# Time for wavefunction update (s):  0.039113759994506836
# Time taken for forward SHT (s):  0.12882542610168457
# Time taken for integration at r_orbit (s):  1.511195421218872
# Time taken for inverse SHT at r_orbit (s):  0.0015416145324707031
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0017292499542236328
# Time for updating particle position and interpolating acc (s):  0.11852002143859863
# Star position (r, theta, phi) in kpc:  [0.19912423 1.84605305 3.14274906]
# Time for wavefunction update (s):  0.027227163314819336
# Time taken for forward SHT (s):  0.1159372329711914
# Time taken for integration at r_orbit (s):  1.2954802513122559
# Time taken for inverse SHT at r_orbit (s):  0.0020880699157714844
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029380321502685547
# Time for updating particle position and interpolating acc (s):  0.1800403594970703
# Star position (r, theta, phi) in kpc:  [0.2006209  1.91206828 3.14271121]
# Time for wavefunction update (s):  0.03825974464416504
# Time taken for forward SHT (s):  0.1159677505493164
# Time taken for integration at r_orbit (s):  0.0346832275390625
# Time taken for inverse SHT at r_orbit (s):  0.001996278762817383
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028998851776123047
# Time for updating particle position and interpolating acc (s):  0.1793224811553955
# Star position (r, theta, phi) in kpc:  [0.20174216 1.97724023 3.14267457]
# Time for wavefunction update (s):  0.0455625057220459
# Time taken for forward SHT (s):  0.11573100090026855
# Time taken for integration at r_orbit (s):  1.3808977603912354
# Time taken for inverse SHT at r_orbit (s):  0.002092123031616211
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002938985824584961
# Time for updating particle position and interpolating acc (s):  0.17957377433776855
# Star position (r, theta, phi) in kpc:  [0.20278253 2.04173004 3.14262825]
# Time for wavefunction update (s):  0.03879547119140625
# Time taken for forward SHT (s):  0.1288154125213623
# Time taken for integration at r_orbit (s):  0.03544902801513672
# Time taken for inverse SHT at r_orbit (s):  0.0020341873168945312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029144287109375
# Time for updating particle position and interpolating acc (s):  0.17529749870300293
# Step 50/1000
# Star position (r, theta, phi) in kpc:  [0.20389646 2.10553069 3.14258302]
# Time for wavefunction update (s):  0.04600667953491211
# Time taken for forward SHT (s):  0.11582064628601074
# Time taken for integration at r_orbit (s):  1.4737496376037598
# Time taken for inverse SHT at r_orbit (s):  0.0020780563354492188
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029342174530029297
# Time for updating particle position and interpolating acc (s):  0.1808764934539795
# Star position (r, theta, phi) in kpc:  [0.20468297 2.16870584 3.14254441]
# Time for wavefunction update (s):  0.03881430625915527
# Time taken for forward SHT (s):  0.1182699203491211
# Time taken for integration at r_orbit (s):  0.03268551826477051
# Time taken for inverse SHT at r_orbit (s):  0.0019414424896240234
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002695798873901367
# Time for updating particle position and interpolating acc (s):  0.1712636947631836
# Star position (r, theta, phi) in kpc:  [0.20500525 2.23157108 3.14249161]
# Time for wavefunction update (s):  0.03439068794250488
# Time taken for forward SHT (s):  0.12283182144165039
# Time taken for integration at r_orbit (s):  0.032532453536987305
# Time taken for inverse SHT at r_orbit (s):  0.0019104480743408203
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0026628971099853516
# Time for updating particle position and interpolating acc (s):  0.13719487190246582
# Star position (r, theta, phi) in kpc:  [0.20535474 2.29425879 3.1424095 ]
# Time for wavefunction update (s):  0.03361701965332031
# Time taken for forward SHT (s):  0.11584115028381348
# Time taken for integration at r_orbit (s):  1.36061429977417
# Time taken for inverse SHT at r_orbit (s):  0.0020475387573242188
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029251575469970703
# Time for updating particle position and interpolating acc (s):  0.18965625762939453
# Star position (r, theta, phi) in kpc:  [0.20553667 2.35673264 3.14230075]
# Time for wavefunction update (s):  0.04030609130859375
# Time taken for forward SHT (s):  0.11632251739501953
# Time taken for integration at r_orbit (s):  0.03651762008666992
# Time taken for inverse SHT at r_orbit (s):  0.0020461082458496094
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029451847076416016
# Time for updating particle position and interpolating acc (s):  0.18227910995483398
# Star position (r, theta, phi) in kpc:  [0.20484725 2.41933281 3.14217908]
# Time for wavefunction update (s):  0.03891801834106445
# Time taken for forward SHT (s):  0.11624407768249512
# Time taken for integration at r_orbit (s):  0.036988019943237305
# Time taken for inverse SHT at r_orbit (s):  0.0024747848510742188
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.003545999526977539
# Time for updating particle position and interpolating acc (s):  0.18352818489074707
# Star position (r, theta, phi) in kpc:  [0.2036422  2.48257764 3.1420579 ]
# Time for wavefunction update (s):  0.044573307037353516
# Time taken for forward SHT (s):  0.11605548858642578
# Time taken for integration at r_orbit (s):  0.03628206253051758
# Time taken for inverse SHT at r_orbit (s):  0.0030536651611328125
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.00402522087097168
# Time for updating particle position and interpolating acc (s):  0.18007874488830566
# Star position (r, theta, phi) in kpc:  [0.20255241 2.5465427  3.14191078]
# Time for wavefunction update (s):  0.03800559043884277
# Time taken for forward SHT (s):  0.1160888671875
# Time taken for integration at r_orbit (s):  0.035181283950805664
# Time taken for inverse SHT at r_orbit (s):  0.001982450485229492
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029010772705078125
# Time for updating particle position and interpolating acc (s):  0.18816494941711426
# Star position (r, theta, phi) in kpc:  [0.20125545 2.61122769 3.14174422]
# Time for wavefunction update (s):  0.04021906852722168
# Time taken for forward SHT (s):  0.1160268783569336
# Time taken for integration at r_orbit (s):  0.040654659271240234
# Time taken for inverse SHT at r_orbit (s):  0.0021419525146484375
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.003139019012451172
# Time for updating particle position and interpolating acc (s):  0.18038582801818848
# Star position (r, theta, phi) in kpc:  [0.1996329  2.67688153 3.1415732 ]
# Time for wavefunction update (s):  0.038941144943237305
# Time taken for forward SHT (s):  0.11602139472961426
# Time taken for integration at r_orbit (s):  0.037817955017089844
# Time taken for inverse SHT at r_orbit (s):  0.001987934112548828
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028896331787109375
# Time for updating particle position and interpolating acc (s):  0.18009042739868164
# Step 60/1000
# Star position (r, theta, phi) in kpc:  [0.19774812 2.7436779  3.14137351]
# Time for wavefunction update (s):  0.04529547691345215
# Time taken for forward SHT (s):  0.1156303882598877
# Time taken for integration at r_orbit (s):  0.036922454833984375
# Time taken for inverse SHT at r_orbit (s):  0.0019860267639160156
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.00287628173828125
# Time for updating particle position and interpolating acc (s):  0.18075156211853027
# Star position (r, theta, phi) in kpc:  [0.19596568 2.81178274 3.14109617]
# Time for wavefunction update (s):  0.038290977478027344
# Time taken for forward SHT (s):  0.11604785919189453
# Time taken for integration at r_orbit (s):  0.037241458892822266
# Time taken for inverse SHT at r_orbit (s):  0.0020036697387695312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028700828552246094
# Time for updating particle position and interpolating acc (s):  0.1796402931213379
# Star position (r, theta, phi) in kpc:  [0.1943892  2.88101732 3.14063284]
# Time for wavefunction update (s):  0.03835892677307129
# Time taken for forward SHT (s):  0.11605286598205566
# Time taken for integration at r_orbit (s):  0.036609649658203125
# Time taken for inverse SHT at r_orbit (s):  0.002002716064453125
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002904653549194336
# Time for updating particle position and interpolating acc (s):  0.17927980422973633
# Star position (r, theta, phi) in kpc:  [0.19238578 2.95151635 3.13976678]
# Time for wavefunction update (s):  0.045304059982299805
# Time taken for forward SHT (s):  0.11575508117675781
# Time taken for integration at r_orbit (s):  0.03673958778381348
# Time taken for inverse SHT at r_orbit (s):  0.001959562301635742
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029408931732177734
# Time for updating particle position and interpolating acc (s):  0.18097758293151855
# Star position (r, theta, phi) in kpc:  [0.18980021 3.02372274 3.13773941]
# Time for wavefunction update (s):  0.03869032859802246
# Time taken for forward SHT (s):  0.11593151092529297
# Time taken for integration at r_orbit (s):  0.03704094886779785
# Time taken for inverse SHT at r_orbit (s):  0.0019860267639160156
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028595924377441406
# Time for updating particle position and interpolating acc (s):  0.17934846878051758
# Star position (r, theta, phi) in kpc:  [0.18723231 3.09798507 3.12866594]
# Time for wavefunction update (s):  0.03848075866699219
# Time taken for forward SHT (s):  0.11602091789245605
# Time taken for integration at r_orbit (s):  0.03710532188415527
# Time taken for inverse SHT at r_orbit (s):  0.0019826889038085938
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028808116912841797
# Time for updating particle position and interpolating acc (s):  1.7099192142486572
# Star position (r, theta, phi) in kpc:  [0.18500392 3.10902946 0.02072632]
# Time for wavefunction update (s):  0.03800535202026367
# Time taken for forward SHT (s):  0.1298658847808838
# Time taken for integration at r_orbit (s):  0.03722047805786133
# Time taken for inverse SHT at r_orbit (s):  0.0020313262939453125
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028831958770751953
# Time for updating particle position and interpolating acc (s):  0.5395176410675049
# Star position (r, theta, phi) in kpc:  [0.18271582 3.03101486 0.00716755]
# Time for wavefunction update (s):  0.03814554214477539
# Time taken for forward SHT (s):  0.11594820022583008
# Time taken for integration at r_orbit (s):  0.03707170486450195
# Time taken for inverse SHT at r_orbit (s):  0.0019729137420654297
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.00286865234375
# Time for updating particle position and interpolating acc (s):  0.36165881156921387
# Star position (r, theta, phi) in kpc:  [0.18067841 2.951058   0.00478837]
# Time for wavefunction update (s):  0.038143157958984375
# Time taken for forward SHT (s):  0.1160740852355957
# Time taken for integration at r_orbit (s):  0.03714156150817871
# Time taken for inverse SHT at r_orbit (s):  0.001981496810913086
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028929710388183594
# Time for updating particle position and interpolating acc (s):  0.32588815689086914
# Star position (r, theta, phi) in kpc:  [0.17914281 2.86953999 0.00374148]
# Time for wavefunction update (s):  0.038170814514160156
# Time taken for forward SHT (s):  0.11600875854492188
# Time taken for integration at r_orbit (s):  1.347055435180664
# Time taken for inverse SHT at r_orbit (s):  0.0020465850830078125
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029473304748535156
# Time for updating particle position and interpolating acc (s):  0.35538244247436523
# Step 70/1000
# Star position (r, theta, phi) in kpc:  [0.1777275  2.78669375 0.00311865]
# Time for wavefunction update (s):  0.039110660552978516
# Time taken for forward SHT (s):  0.12803339958190918
# Time taken for integration at r_orbit (s):  1.4524800777435303
# Time taken for inverse SHT at r_orbit (s):  0.0020651817321777344
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028753280639648438
# Time for updating particle position and interpolating acc (s):  0.3539314270019531
# Star position (r, theta, phi) in kpc:  [0.17661349 2.70261238 0.00271623]
# Time for wavefunction update (s):  0.03833460807800293
# Time taken for forward SHT (s):  0.12871789932250977
# Time taken for integration at r_orbit (s):  0.03468751907348633
# Time taken for inverse SHT at r_orbit (s):  0.0020279884338378906
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028450489044189453
# Time for updating particle position and interpolating acc (s):  0.31969356536865234
# Star position (r, theta, phi) in kpc:  [1.76226848e-01 2.61780111e+00 2.45951066e-03]
# Time for wavefunction update (s):  0.03867936134338379
# Time taken for forward SHT (s):  0.11608219146728516
# Time taken for integration at r_orbit (s):  1.3704519271850586
# Time taken for inverse SHT at r_orbit (s):  0.0021257400512695312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029077529907226562
# Time for updating particle position and interpolating acc (s):  0.2798197269439697
# Star position (r, theta, phi) in kpc:  [1.76600120e-01 2.53299435e+00 2.26850245e-03]
# Time for wavefunction update (s):  0.03773093223571777
# Time taken for forward SHT (s):  0.12888693809509277
# Time taken for integration at r_orbit (s):  0.03506064414978027
# Time taken for inverse SHT at r_orbit (s):  0.002031087875366211
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028839111328125
# Time for updating particle position and interpolating acc (s):  0.3130815029144287
# Star position (r, theta, phi) in kpc:  [1.77118530e-01 2.44870288e+00 2.08482310e-03]
# Time for wavefunction update (s):  0.03802967071533203
# Time taken for forward SHT (s):  0.11656594276428223
# Time taken for integration at r_orbit (s):  0.03461885452270508
# Time taken for inverse SHT at r_orbit (s):  0.0019850730895996094
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028543472290039062
# Time for updating particle position and interpolating acc (s):  0.3117995262145996
# Star position (r, theta, phi) in kpc:  [1.77750705e-01 2.36487832e+00 1.90994962e-03]
# Time for wavefunction update (s):  0.03752279281616211
# Time taken for forward SHT (s):  0.11682939529418945
# Time taken for integration at r_orbit (s):  0.03477668762207031
# Time taken for inverse SHT at r_orbit (s):  0.00199127197265625
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002845287322998047
# Time for updating particle position and interpolating acc (s):  0.31290578842163086
# Star position (r, theta, phi) in kpc:  [1.78941680e-01 2.28191849e+00 1.75488536e-03]
# Time for wavefunction update (s):  0.0382230281829834
# Time taken for forward SHT (s):  0.11671829223632812
# Time taken for integration at r_orbit (s):  0.03463888168334961
# Time taken for inverse SHT at r_orbit (s):  0.0019829273223876953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.00286865234375
# Time for updating particle position and interpolating acc (s):  0.3126189708709717
# Star position (r, theta, phi) in kpc:  [1.80566652e-01 2.20024901e+00 1.62411706e-03]
# Time for wavefunction update (s):  0.03774142265319824
# Time taken for forward SHT (s):  0.11662411689758301
# Time taken for integration at r_orbit (s):  0.03464913368225098
# Time taken for inverse SHT at r_orbit (s):  0.001961231231689453
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028448104858398438
# Time for updating particle position and interpolating acc (s):  0.35407018661499023
# Star position (r, theta, phi) in kpc:  [1.82307863e-01 2.12011973e+00 1.51084826e-03]
# Time for wavefunction update (s):  0.03811001777648926
# Time taken for forward SHT (s):  0.11673259735107422
# Time taken for integration at r_orbit (s):  0.03476238250732422
# Time taken for inverse SHT at r_orbit (s):  0.002035379409790039
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028803348541259766
# Time for updating particle position and interpolating acc (s):  0.32426905632019043
# Star position (r, theta, phi) in kpc:  [1.84009939e-01 2.04147307e+00 1.39073317e-03]
# Time for wavefunction update (s):  0.03859758377075195
# Time taken for forward SHT (s):  0.11661839485168457
# Time taken for integration at r_orbit (s):  0.034554481506347656
# Time taken for inverse SHT at r_orbit (s):  0.001981496810913086
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002863645553588867
# Time for updating particle position and interpolating acc (s):  0.29317140579223633
# Step 80/1000
# Star position (r, theta, phi) in kpc:  [1.85962351e-01 1.96435680e+00 1.26257128e-03]
# Time for wavefunction update (s):  0.03739786148071289
# Time taken for forward SHT (s):  0.11673498153686523
# Time taken for integration at r_orbit (s):  0.03462576866149902
# Time taken for inverse SHT at r_orbit (s):  0.0019834041595458984
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002854585647583008
# Time for updating particle position and interpolating acc (s):  0.3174915313720703
# Star position (r, theta, phi) in kpc:  [1.88151472e-01 1.88897171e+00 1.15021290e-03]
# Time for wavefunction update (s):  0.038010358810424805
# Time taken for forward SHT (s):  0.11654114723205566
# Time taken for integration at r_orbit (s):  0.03649449348449707
# Time taken for inverse SHT at r_orbit (s):  0.001978158950805664
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028429031372070312
# Time for updating particle position and interpolating acc (s):  0.31798338890075684
# Star position (r, theta, phi) in kpc:  [1.90201583e-01 1.81529784e+00 1.06143174e-03]
# Time for wavefunction update (s):  0.03781270980834961
# Time taken for forward SHT (s):  0.11660599708557129
# Time taken for integration at r_orbit (s):  0.03464698791503906
# Time taken for inverse SHT at r_orbit (s):  0.001980304718017578
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002858877182006836
# Time for updating particle position and interpolating acc (s):  0.3171854019165039
# Star position (r, theta, phi) in kpc:  [1.92139702e-01 1.74312547e+00 9.76544274e-04]
# Time for wavefunction update (s):  0.03756380081176758
# Time taken for forward SHT (s):  0.11659646034240723
# Time taken for integration at r_orbit (s):  0.03457808494567871
# Time taken for inverse SHT at r_orbit (s):  0.0019712448120117188
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028514862060546875
# Time for updating particle position and interpolating acc (s):  0.3166618347167969
# Star position (r, theta, phi) in kpc:  [1.94280047e-01 1.67245096e+00 8.80001732e-04]
# Time for wavefunction update (s):  0.0377500057220459
# Time taken for forward SHT (s):  0.1167135238647461
# Time taken for integration at r_orbit (s):  0.03472089767456055
# Time taken for inverse SHT at r_orbit (s):  0.0019707679748535156
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002846240997314453
# Time for updating particle position and interpolating acc (s):  0.3172321319580078
# Star position (r, theta, phi) in kpc:  [1.96186366e-01 1.60330760e+00 7.68821416e-04]
# Time for wavefunction update (s):  0.03769207000732422
# Time taken for forward SHT (s):  0.11661052703857422
# Time taken for integration at r_orbit (s):  0.03456473350524902
# Time taken for inverse SHT at r_orbit (s):  0.0019881725311279297
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002838134765625
# Time for updating particle position and interpolating acc (s):  0.3160731792449951
# Star position (r, theta, phi) in kpc:  [1.97409569e-01 1.53525744e+00 6.52939655e-04]
# Time for wavefunction update (s):  0.03793931007385254
# Time taken for forward SHT (s):  0.11665153503417969
# Time taken for integration at r_orbit (s):  0.03472161293029785
# Time taken for inverse SHT at r_orbit (s):  0.0019714832305908203
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028603076934814453
# Time for updating particle position and interpolating acc (s):  0.2821352481842041
# Star position (r, theta, phi) in kpc:  [1.98400149e-01 1.46791655e+00 5.38341043e-04]
# Time for wavefunction update (s):  0.03769230842590332
# Time taken for forward SHT (s):  0.11651825904846191
# Time taken for integration at r_orbit (s):  0.03468823432922363
# Time taken for inverse SHT at r_orbit (s):  0.0019638538360595703
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002849102020263672
# Time for updating particle position and interpolating acc (s):  0.3180112838745117
# Star position (r, theta, phi) in kpc:  [1.99378180e-01 1.40124693e+00 4.13968454e-04]
# Time for wavefunction update (s):  0.03806900978088379
# Time taken for forward SHT (s):  0.11652588844299316
# Time taken for integration at r_orbit (s):  0.03449368476867676
# Time taken for inverse SHT at r_orbit (s):  0.0019621849060058594
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028486251831054688
# Time for updating particle position and interpolating acc (s):  0.31713342666625977
# Star position (r, theta, phi) in kpc:  [2.00490645e-01 1.33523219e+00 2.85257968e-04]
# Time for wavefunction update (s):  0.03805088996887207
# Time taken for forward SHT (s):  0.1165320873260498
# Time taken for integration at r_orbit (s):  0.03467679023742676
# Time taken for inverse SHT at r_orbit (s):  0.0019922256469726562
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028634071350097656
# Time for updating particle position and interpolating acc (s):  0.31877923011779785
# Step 90/1000
# Star position (r, theta, phi) in kpc:  [2.01600864e-01 1.26999193e+00 1.57701895e-04]
# Time for wavefunction update (s):  0.03784823417663574
# Time taken for forward SHT (s):  0.11654520034790039
# Time taken for integration at r_orbit (s):  0.0347597599029541
# Time taken for inverse SHT at r_orbit (s):  0.0019676685333251953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002862215042114258
# Time for updating particle position and interpolating acc (s):  0.28258562088012695
# Star position (r, theta, phi) in kpc:  [2.02510477e-01 1.20537798e+00 2.98210810e-05]
# Time for wavefunction update (s):  0.03783416748046875
# Time taken for forward SHT (s):  0.11666369438171387
# Time taken for integration at r_orbit (s):  0.0347292423248291
# Time taken for inverse SHT at r_orbit (s):  0.001984119415283203
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002854585647583008
# Time for updating particle position and interpolating acc (s):  0.35305047035217285
# Star position (r, theta, phi) in kpc:  [0.20335193 1.14132148 6.2830872 ]
# Time for wavefunction update (s):  0.03787708282470703
# Time taken for forward SHT (s):  0.11634159088134766
# Time taken for integration at r_orbit (s):  0.03659677505493164
# Time taken for inverse SHT at r_orbit (s):  0.0019686222076416016
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028769969940185547
# Time for updating particle position and interpolating acc (s):  0.2823960781097412
# Star position (r, theta, phi) in kpc:  [0.20421007 1.07778278 6.28295688]
# Time for wavefunction update (s):  0.03798198699951172
# Time taken for forward SHT (s):  0.11663222312927246
# Time taken for integration at r_orbit (s):  0.03478884696960449
# Time taken for inverse SHT at r_orbit (s):  0.0019903182983398438
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028541088104248047
# Time for updating particle position and interpolating acc (s):  0.3169066905975342
# Star position (r, theta, phi) in kpc:  [0.20512197 1.01481873 6.28281502]
# Time for wavefunction update (s):  0.03786325454711914
# Time taken for forward SHT (s):  0.11653947830200195
# Time taken for integration at r_orbit (s):  0.036446332931518555
# Time taken for inverse SHT at r_orbit (s):  0.001971721649169922
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028717517852783203
# Time for updating particle position and interpolating acc (s):  0.35006022453308105
# Star position (r, theta, phi) in kpc:  [0.2058066  0.95236688 6.28265035]
# Time for wavefunction update (s):  0.03853774070739746
# Time taken for forward SHT (s):  0.11665797233581543
# Time taken for integration at r_orbit (s):  0.03480935096740723
# Time taken for inverse SHT at r_orbit (s):  0.001960277557373047
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028684139251708984
# Time for updating particle position and interpolating acc (s):  0.318864107131958
# Star position (r, theta, phi) in kpc:  [0.20638314 0.89027682 6.28245971]
# Time for wavefunction update (s):  0.03713417053222656
# Time taken for forward SHT (s):  0.1166837215423584
# Time taken for integration at r_orbit (s):  0.034761905670166016
# Time taken for inverse SHT at r_orbit (s):  0.001971006393432617
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028562545776367188
# Time for updating particle position and interpolating acc (s):  0.2830390930175781
# Star position (r, theta, phi) in kpc:  [0.20720817 0.82859983 6.28223783]
# Time for wavefunction update (s):  0.037844181060791016
# Time taken for forward SHT (s):  0.11654496192932129
# Time taken for integration at r_orbit (s):  1.2961373329162598
# Time taken for inverse SHT at r_orbit (s):  0.0020864009857177734
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029511451721191406
# Time for updating particle position and interpolating acc (s):  0.2878708839416504
# Star position (r, theta, phi) in kpc:  [0.20824902 0.76748966 6.28197405]
# Time for wavefunction update (s):  0.4006204605102539
# Time taken for forward SHT (s):  0.12839245796203613
# Time taken for integration at r_orbit (s):  0.03502821922302246
# Time taken for inverse SHT at r_orbit (s):  0.0020101070404052734
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029125213623046875
# Time for updating particle position and interpolating acc (s):  0.28771424293518066
# Star position (r, theta, phi) in kpc:  [0.20943611 0.7070212  6.28165663]
# Time for wavefunction update (s):  0.03824353218078613
# Time taken for forward SHT (s):  0.11669063568115234
# Time taken for integration at r_orbit (s):  1.3623275756835938
# Time taken for inverse SHT at r_orbit (s):  0.002079010009765625
# (3, 24, 47) (3,)
# ...
# Time for wavefunction update (s):  0.03801679611206055
# Time taken for forward SHT (s):  0.11671900749206543
# Time taken for integration at r_orbit (s):  0.03862953186035156
# Time taken for inverse SHT at r_orbit (s):  0.0020275115966796875
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002882242202758789
# Time for updating particle position and interpolating acc (s):  0.32158803939819336
# Star position (r, theta, phi) in kpc:  [0.28929617 2.24027331 3.14219031]
# Time for wavefunction update (s):  0.03828287124633789
# Time taken for forward SHT (s):  0.11692976951599121
# Time taken for integration at r_orbit (s):  0.03869175910949707
# Time taken for inverse SHT at r_orbit (s):  0.0019979476928710938
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002874612808227539
# Time for updating particle position and interpolating acc (s):  0.3225123882293701
# Star position (r, theta, phi) in kpc:  [0.28331506 2.27244676 3.14215016]
# Time for wavefunction update (s):  0.03759288787841797
# Time taken for forward SHT (s):  0.11660194396972656
# Time taken for integration at r_orbit (s):  0.03839254379272461
# Time taken for inverse SHT at r_orbit (s):  0.001993417739868164
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002874135971069336
# Time for updating particle position and interpolating acc (s):  0.3217813968658447
# Star position (r, theta, phi) in kpc:  [0.27617856 2.30612547 3.14211194]
# Time for wavefunction update (s):  0.037451982498168945
# Time taken for forward SHT (s):  0.11660528182983398
# Time taken for integration at r_orbit (s):  0.03830432891845703
# Time taken for inverse SHT at r_orbit (s):  0.0019872188568115234
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028870105743408203
# Time for updating particle position and interpolating acc (s):  0.3209547996520996
# Star position (r, theta, phi) in kpc:  [0.26770008 2.34178821 3.14206875]
# Time for wavefunction update (s):  0.037917375564575195
# Time taken for forward SHT (s):  0.11657166481018066
# Time taken for integration at r_orbit (s):  0.03831934928894043
# Time taken for inverse SHT at r_orbit (s):  0.001992940902709961
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028944015502929688
# Time for updating particle position and interpolating acc (s):  0.3210737705230713
# Star position (r, theta, phi) in kpc:  [0.25796548 2.3799518  3.14201328]
# Time for wavefunction update (s):  0.03757333755493164
# Time taken for forward SHT (s):  0.1165919303894043
# Time taken for integration at r_orbit (s):  0.03659415245056152
# Time taken for inverse SHT at r_orbit (s):  0.0020051002502441406
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028493404388427734
# Time for updating particle position and interpolating acc (s):  0.32078003883361816
# Step 510/1000
# Star position (r, theta, phi) in kpc:  [0.24730312 2.42130472 3.141942  ]
# Time for wavefunction update (s):  0.03744387626647949
# Time taken for forward SHT (s):  0.11663103103637695
# Time taken for integration at r_orbit (s):  0.038511037826538086
# Time taken for inverse SHT at r_orbit (s):  0.0020062923431396484
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028815269470214844
# Time for updating particle position and interpolating acc (s):  0.3302018642425537
# Star position (r, theta, phi) in kpc:  [0.23614079 2.46646107 3.14186317]
# Time for wavefunction update (s):  0.037967681884765625
# Time taken for forward SHT (s):  0.11660981178283691
# Time taken for integration at r_orbit (s):  0.0383915901184082
# Time taken for inverse SHT at r_orbit (s):  0.002010822296142578
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028839111328125
# Time for updating particle position and interpolating acc (s):  0.3193037509918213
# Star position (r, theta, phi) in kpc:  [0.22466307 2.5161916  3.14175535]
# Time for wavefunction update (s):  0.03776192665100098
# Time taken for forward SHT (s):  0.11661219596862793
# Time taken for integration at r_orbit (s):  0.0383610725402832
# Time taken for inverse SHT at r_orbit (s):  0.002002716064453125
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028934478759765625
# Time for updating particle position and interpolating acc (s):  0.3197472095489502
# Star position (r, theta, phi) in kpc:  [0.21301028 2.57129297 3.14160238]
# Time for wavefunction update (s):  0.04142284393310547
# Time taken for forward SHT (s):  0.11651253700256348
# Time taken for integration at r_orbit (s):  0.038535356521606445
# Time taken for inverse SHT at r_orbit (s):  0.002012968063354492
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029022693634033203
# Time for updating particle position and interpolating acc (s):  0.32083892822265625
# Star position (r, theta, phi) in kpc:  [0.20128896 2.63282804 3.14138342]
# Time for wavefunction update (s):  0.038048744201660156
# Time taken for forward SHT (s):  0.11668658256530762
# Time taken for integration at r_orbit (s):  0.03867387771606445
# Time taken for inverse SHT at r_orbit (s):  0.002009153366088867
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029044151306152344
# Time for updating particle position and interpolating acc (s):  0.325908899307251
# Star position (r, theta, phi) in kpc:  [0.18956926 2.70193278 3.14107095]
# Time for wavefunction update (s):  0.04242229461669922
# Time taken for forward SHT (s):  0.11673521995544434
# Time taken for integration at r_orbit (s):  0.038654327392578125
# Time taken for inverse SHT at r_orbit (s):  0.002028226852416992
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028848648071289062
# Time for updating particle position and interpolating acc (s):  0.321394681930542
# Star position (r, theta, phi) in kpc:  [0.178012   2.78013395 3.14060526]
# Time for wavefunction update (s):  0.037375688552856445
# Time taken for forward SHT (s):  0.11661195755004883
# Time taken for integration at r_orbit (s):  0.0382695198059082
# Time taken for inverse SHT at r_orbit (s):  0.0019676685333251953
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028679370880126953
# Time for updating particle position and interpolating acc (s):  0.3219873905181885
# Star position (r, theta, phi) in kpc:  [0.1669643  2.86890182 3.13981803]
# Time for wavefunction update (s):  0.03811764717102051
# Time taken for forward SHT (s):  0.11643552780151367
# Time taken for integration at r_orbit (s):  0.03831601142883301
# Time taken for inverse SHT at r_orbit (s):  0.0020189285278320312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029060840606689453
# Time for updating particle position and interpolating acc (s):  0.3224053382873535
# Star position (r, theta, phi) in kpc:  [0.15662459 2.96986043 3.13797053]
# Time for wavefunction update (s):  0.03769564628601074
# Time taken for forward SHT (s):  0.11689019203186035
# Time taken for integration at r_orbit (s):  0.038364410400390625
# Time taken for inverse SHT at r_orbit (s):  0.0019974708557128906
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028994083404541016
# Time for updating particle position and interpolating acc (s):  0.2865116596221924
# Star position (r, theta, phi) in kpc:  [0.14762339 3.08412517 3.12791367]
# Time for wavefunction update (s):  0.03784513473510742
# Time taken for forward SHT (s):  0.1165928840637207
# Time taken for integration at r_orbit (s):  0.038260698318481445
# Time taken for inverse SHT at r_orbit (s):  0.002012491226196289
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028717517852783203
# Time for updating particle position and interpolating acc (s):  0.6368842124938965
# Step 520/1000
# Star position (r, theta, phi) in kpc:  [0.14025691 3.07143388 0.01367547]
# Time for wavefunction update (s):  0.03823232650756836
# Time taken for forward SHT (s):  0.11660027503967285
# Time taken for integration at r_orbit (s):  0.03845834732055664
# Time taken for inverse SHT at r_orbit (s):  0.001995086669921875
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029370784759521484
# Time for updating particle position and interpolating acc (s):  0.3558535575866699
# Star position (r, theta, phi) in kpc:  [0.13480876 2.93158257 0.0054258 ]
# Time for wavefunction update (s):  0.037779808044433594
# Time taken for forward SHT (s):  0.11680436134338379
# Time taken for integration at r_orbit (s):  0.038491249084472656
# Time taken for inverse SHT at r_orbit (s):  0.0020170211791992188
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029015541076660156
# Time for updating particle position and interpolating acc (s):  0.3318755626678467
# Star position (r, theta, phi) in kpc:  [0.13149644 2.78242795 0.00369884]
# Time for wavefunction update (s):  0.03766274452209473
# Time taken for forward SHT (s):  0.11650276184082031
# Time taken for integration at r_orbit (s):  1.5308303833007812
# Time taken for inverse SHT at r_orbit (s):  0.002079486846923828
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029795169830322266
# Time for updating particle position and interpolating acc (s):  0.28791189193725586
# Star position (r, theta, phi) in kpc:  [0.13050894 2.62825338 0.00298844]
# Time for wavefunction update (s):  0.03788566589355469
# Time taken for forward SHT (s):  0.12890076637268066
# Time taken for integration at r_orbit (s):  1.4681346416473389
# Time taken for inverse SHT at r_orbit (s):  0.0021560192108154297
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002975940704345703
# Time for updating particle position and interpolating acc (s):  0.32371950149536133
# Star position (r, theta, phi) in kpc:  [0.13209479 2.47478502 0.00261465]
# Time for wavefunction update (s):  0.03971052169799805
# Time taken for forward SHT (s):  0.12853503227233887
# Time taken for integration at r_orbit (s):  0.03884077072143555
# Time taken for inverse SHT at r_orbit (s):  0.0020148754119873047
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028998851776123047
# Time for updating particle position and interpolating acc (s):  0.3214724063873291
# Star position (r, theta, phi) in kpc:  [0.13593013 2.32755669 0.00239364]
# Time for wavefunction update (s):  0.037697792053222656
# Time taken for forward SHT (s):  0.11667275428771973
# Time taken for integration at r_orbit (s):  0.037369489669799805
# Time taken for inverse SHT at r_orbit (s):  0.0020024776458740234
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0029296875
# Time for updating particle position and interpolating acc (s):  0.3633718490600586
# Star position (r, theta, phi) in kpc:  [0.14149963 2.19018629 0.00226847]
# Time for wavefunction update (s):  0.03778529167175293
# Time taken for forward SHT (s):  0.1169130802154541
# Time taken for integration at r_orbit (s):  0.03905057907104492
# Time taken for inverse SHT at r_orbit (s):  0.0020334720611572266
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002971649169921875
# Time for updating particle position and interpolating acc (s):  0.31954264640808105
# Star position (r, theta, phi) in kpc:  [0.14868175 2.06457968 0.00218322]
# Time for wavefunction update (s):  0.03824472427368164
# Time taken for forward SHT (s):  0.11662888526916504
# Time taken for integration at r_orbit (s):  0.036834716796875
# Time taken for inverse SHT at r_orbit (s):  0.002004861831665039
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028672218322753906
# Time for updating particle position and interpolating acc (s):  0.286663293838501
# Star position (r, theta, phi) in kpc:  [0.15745484 1.95173319 0.0021027 ]
# Time for wavefunction update (s):  0.03787994384765625
# Time taken for forward SHT (s):  0.11659455299377441
# Time taken for integration at r_orbit (s):  0.036788225173950195
# Time taken for inverse SHT at r_orbit (s):  0.0020003318786621094
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002896547317504883
# Time for updating particle position and interpolating acc (s):  0.3195962905883789
# Star position (r, theta, phi) in kpc:  [0.16749323 1.85161761 0.00202006]
# Time for wavefunction update (s):  0.03802227973937988
# Time taken for forward SHT (s):  0.11666989326477051
# Time taken for integration at r_orbit (s):  0.03671908378601074
# Time taken for inverse SHT at r_orbit (s):  0.0020110607147216797
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002885103225708008
# Time for updating particle position and interpolating acc (s):  0.3233470916748047
# Step 530/1000
# Star position (r, theta, phi) in kpc:  [0.17790096 1.76312725 0.00192702]
# Time for wavefunction update (s):  0.038614749908447266
# Time taken for forward SHT (s):  0.1171717643737793
# Time taken for integration at r_orbit (s):  0.04016876220703125
# Time taken for inverse SHT at r_orbit (s):  0.0024983882904052734
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0034563541412353516
# Time for updating particle position and interpolating acc (s):  0.3203589916229248
# Star position (r, theta, phi) in kpc:  [0.1884607  1.68441555 0.00182525]
# Time for wavefunction update (s):  0.03784608840942383
# Time taken for forward SHT (s):  0.1166834831237793
# Time taken for integration at r_orbit (s):  0.03705430030822754
# Time taken for inverse SHT at r_orbit (s):  0.0020036697387695312
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002887725830078125
# Time for updating particle position and interpolating acc (s):  0.32123732566833496
# Star position (r, theta, phi) in kpc:  [0.19913249 1.61415882 0.00172724]
# Time for wavefunction update (s):  0.03803730010986328
# Time taken for forward SHT (s):  0.11661696434020996
# Time taken for integration at r_orbit (s):  0.038431406021118164
# Time taken for inverse SHT at r_orbit (s):  0.001990795135498047
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028984546661376953
# Time for updating particle position and interpolating acc (s):  0.32056355476379395
# Star position (r, theta, phi) in kpc:  [0.20973693 1.55099169 0.00164094]
# Time for wavefunction update (s):  0.038133859634399414
# Time taken for forward SHT (s):  0.11656904220581055
# Time taken for integration at r_orbit (s):  0.03863191604614258
# Time taken for inverse SHT at r_orbit (s):  0.0019779205322265625
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002875089645385742
# Time for updating particle position and interpolating acc (s):  0.3239552974700928
# Star position (r, theta, phi) in kpc:  [0.22030744 1.49392872 0.00156029]
# Time for wavefunction update (s):  0.044870615005493164
# Time taken for forward SHT (s):  0.11663150787353516
# Time taken for integration at r_orbit (s):  0.038556814193725586
# Time taken for inverse SHT at r_orbit (s):  0.0031058788299560547
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.00399017333984375
# Time for updating particle position and interpolating acc (s):  0.3204343318939209
# Star position (r, theta, phi) in kpc:  [0.2300847  1.44195051 0.00147043]
# Time for wavefunction update (s):  0.03821206092834473
# Time taken for forward SHT (s):  0.11659049987792969
# Time taken for integration at r_orbit (s):  0.03864097595214844
# Time taken for inverse SHT at r_orbit (s):  0.0019943714141845703
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.002904176712036133
# Time for updating particle position and interpolating acc (s):  0.32152557373046875
# Star position (r, theta, phi) in kpc:  [2.38921374e-01 1.39400393e+00 1.37756775e-03]
# Time for wavefunction update (s):  0.03831958770751953
# Time taken for forward SHT (s):  0.11669921875
# Time taken for integration at r_orbit (s):  0.03961491584777832
# Time taken for inverse SHT at r_orbit (s):  0.0020117759704589844
# (3, 24, 47) (3,)
# Time for acceleration field calculation (s):  0.0028841495513916016
# Time for updating particle position and interpolating acc (s):  0.3199472427368164
# Star position (r, theta, phi) in kpc:  [2.47417492e-01 1.34940258e+00 1.28500382e-03]
# Time for wavefunction update (s):  0.037807464599609375
# Time taken for forward SHT (s):  0.11659049987792969

# %% [markdown]
# ## Showing velocity and speed distributions by the end of the simulation
# ## Showing the growth of the average radial position of the particle and its velocity dispersion

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))

ax[0].hist(velocities[:,0] * u.to_kms, bins=20)
ax[0].axvline(0, color='red', ls='--', label='Initial Star Velocity')
ax[0].set_xlabel(r"$v_r \;\;\mathrm{[km/s]}$", fontsize = 15)
ax[0].set_ylabel("Frequency", fontsize = 15)

ax[1].hist(velocities[:,1] * u.to_kms, bins=20)
ax[1].axvline(0, color='red', ls='--', label='Initial Star Velocity')
ax[1].set_xlabel(r"$v_\theta \;\;\mathrm{[km/s]}$", fontsize = 15)
ax[1].set_ylabel("Frequency", fontsize = 15)

acc_mag = SSF.Find_acc_mag_from_Phi(r, Phi_psi, r_orbit)

init_vel = np.sqrt(acc_mag * r_orbit) * np.array([0, 1, 0])

init_vel_sph = SSF.Cartesian_to_sph_vel(init_pos[0], init_pos[1], init_pos[2], init_vel[0], init_vel[1], init_vel[2])

ax[2].hist(velocities[:,2] * u.to_kms, bins=20)
ax[2].set_xlabel(r"$v_\phi \;\;\mathrm{[km/s]}$", fontsize = 15)
ax[2].axvline(init_vel_sph[2] * u.to_kms, color='red', ls='--', label='Initial Star Velocity')
ax[2].set_ylabel("Frequency", fontsize = 15)
ax[2].legend(fontsize = 14)
plt.show()

fig, ax = plt.subplots(figsize=(6, 6))

speeds = jnp.sqrt(velocities[:,0]**2 + velocities[:,1]**2 + velocities[:,2]**2)
avg_speed = jnp.mean(speeds)
ax.hist(speeds * u.to_kms, bins=20)
ax.axvline(avg_speed * u.to_kms, color='orange', ls='--', label='Average Star Speed')
ax.axvline(np.sqrt(init_vel_sph[0]**2 + init_vel_sph[1]**2 + init_vel_sph[2]**2) * u.to_kms, color='red', ls='--', label='Initial Star Speed')
ax.set_xlabel(r"$V \;\;\mathrm{[km/s]}$", fontsize = 15)
ax.set_ylabel("Frequency", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()


fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(np.arange(num_steps) * dt * u.to_Gyr, jnp.array(total_avg_r) * u.to_Kpc, label='Average Radial Distance from Halo Center', ls='--')
#ax.plot(np.arange(num_steps) * dt * u.to_Gyr, jnp.array(r_values) * u.to_Kpc, label='Star Radial Distance from Halo Center', ls='-')
ax.axhline(r_orbit * u.to_Kpc, color='red', ls=':', label='Initial Orbit Radius')
ax.set_ylabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
ax.set_xlabel(r"Gyr", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

fig, ax = plt.subplots()

stellar_v_disp = jnp.array(stellar_v_disp)


ax.plot(np.arange(num_steps) * dt * u.to_Gyr, stellar_v_disp * u.to_kms, label='Stellar Velocity Dispersion')
plt.yscale('log')
ax.set_ylabel(r"$\sigma_v \;\;\mathrm{[km/s]}$", fontsize = 15)
ax.set_xlabel(r"Gyr", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# # Convergence testing

# %%
importlib.reload(SSF)

total_evolve_time = 5 * u.from_Gyr
num_steps = np.logspace(1, np.log10(3000), 6).astype(int)
print(num_steps)

r = np.logspace(np.log10(rmin), np.log10(rmax), 1000)

r_orbit = 0.19 * u.from_Kpc

init_pos = np.array([r_orbit, 0, 0]) #Starting as position (r_vir, 0, 0) = (x, y, z)

print("Star initial position (kpc): ", init_pos * u.to_Kpc)

eigen_energies = eigenstate_lib.radial_eigenmode_params.E  # shape (Nj,)
total_mass = wavefunction_params.total_mass
R_j_r = eval_library(r, eigenstate_lib.radial_eigenmode_params)
l = eigenstate_lib.radial_eigenmode_params.l

aj_2 = wavefunction_params.aj_2        # shape (Nj,)
rand_phase = jax.random.uniform(jax.random.PRNGKey(0), shape=aj_2.shape, minval=0.0, maxval=2 * jnp.pi,)
aj = np.sqrt(aj_2) * np.exp(1j * rand_phase)  # shape (Nj,)


total_avg_r_conv = []
stellar_v_disp_conv = []

for n_steps in num_steps:
    dt = total_evolve_time / n_steps
    print("Number of steps: ", n_steps)
    stellar_v_disp, total_avg_r, r_values, velocities = SSF.Simulate_time_dep_3d_Hanno_Reins(r_orbit, init_pos, dt, n_steps, r, eigen_energies, l, R_j_r, aj, total_mass, Phi_psi, Y_lms, print_every = 10)
    total_avg_r_conv.append(total_avg_r)
    stellar_v_disp_conv.append(stellar_v_disp)
# Out:
# [  10   31   97  306  958 3000]
# Star initial position (kpc):  [0.19 0.   0.  ]
# Number of steps:  10
# Number of steps:  31
# Step 10/31
# Step 20/31
# Number of steps:  97
# Step 10/97
# Step 20/97
# Step 30/97
# Step 40/97
# Step 50/97
# Step 60/97
# Step 70/97
# Step 80/97
# Step 90/97
# Number of steps:  306
# Step 10/306
# Step 20/306
# Step 30/306
# Step 40/306
# Step 50/306
# Step 60/306
# Step 70/306
# Step 80/306
# Step 90/306
# Step 100/306
# Step 110/306
# Step 120/306
# Step 130/306
# Step 140/306
# Step 150/306
# Step 160/306
# Step 170/306
# Step 180/306
# Step 190/306
# Step 200/306
# Step 210/306
# Step 220/306
# Step 230/306
# Step 240/306
# Step 250/306
# Step 260/306
# Step 270/306
# Step 280/306
# Step 290/306
# Step 300/306
# Number of steps:  958
# Step 10/958
# Step 20/958
# Step 30/958
# Step 40/958
# Step 50/958
# Step 60/958
# Step 70/958
# Step 80/958
# Step 90/958
# Step 100/958
# Step 110/958
# Step 120/958
# Step 130/958
# Step 140/958
# Step 150/958
# Step 160/958
# Step 170/958
# Step 180/958
# Step 190/958
# Step 200/958
# Step 210/958
# Step 220/958
# Step 230/958
# Step 240/958
# Step 250/958
# Step 260/958
# Step 270/958
# Step 280/958
# Step 290/958
# Step 300/958
# Step 310/958
# Step 320/958
# Step 330/958
# Step 340/958
# Step 350/958
# Step 360/958
# Step 370/958
# Step 380/958
# Step 390/958
# Step 400/958
# Step 410/958
# Step 420/958
# Step 430/958
# Step 440/958
# Step 450/958
# Step 460/958
# Step 470/958
# Step 480/958
# Step 490/958
# Step 500/958
# Step 510/958
# Step 520/958
# Step 530/958
# Step 540/958
# Step 550/958
# Step 560/958
# Step 570/958
# Step 580/958
# Step 590/958
# Step 600/958
# Step 610/958
# Step 620/958
# Step 630/958
# Step 640/958
# Step 650/958
# Step 660/958
# Step 670/958
# Step 680/958
# Step 690/958
# Step 700/958
# Step 710/958
# Step 720/958
# Step 730/958
# Step 740/958
# Step 750/958
# Step 760/958
# Step 770/958
# Step 780/958
# Step 790/958
# Step 800/958
# Step 810/958
# Step 820/958
# Step 830/958
# Step 840/958
# Step 850/958
# Step 860/958
# Step 870/958
# Step 880/958
# Step 890/958
# Step 900/958
# Step 910/958
# Step 920/958
# Step 930/958
# Step 940/958
# Step 950/958
# Number of steps:  3000
# Step 10/3000
# Step 20/3000
# Step 30/3000
# Step 40/3000
# Step 50/3000
# Step 60/3000
# Step 70/3000
# Step 80/3000
# Step 90/3000
# Step 100/3000
# Step 110/3000
# Step 120/3000
# Step 130/3000
# Step 140/3000
# Step 150/3000
# Step 160/3000
# Step 170/3000
# Step 180/3000
# Step 190/3000
# Step 200/3000
# Step 210/3000
# Step 220/3000
# Step 230/3000
# Step 240/3000
# Step 250/3000
# Step 260/3000
# Step 270/3000
# Step 280/3000
# Step 290/3000
# Step 300/3000
# Step 310/3000
# Step 320/3000
# Step 330/3000
# Step 340/3000
# Step 350/3000
# Step 360/3000
# Step 370/3000
# Step 380/3000
# Step 390/3000
# Step 400/3000
# Step 410/3000
# Step 420/3000
# Step 430/3000
# Step 440/3000
# Step 450/3000
# Step 460/3000
# Step 470/3000
# Step 480/3000
# Step 490/3000
# Step 500/3000
# Step 510/3000
# Step 520/3000
# Step 530/3000
# Step 540/3000
# Step 550/3000
# Step 560/3000
# Step 570/3000
# Step 580/3000
# Step 590/3000
# Step 600/3000
# Step 610/3000
# Step 620/3000
# Step 630/3000
# Step 640/3000
# Step 650/3000
# Step 660/3000
# Step 670/3000
# Step 680/3000
# Step 690/3000
# Step 700/3000
# Step 710/3000
# Step 720/3000
# Step 730/3000
# Step 740/3000
# Step 750/3000
# Step 760/3000
# Step 770/3000
# Step 780/3000
# Step 790/3000
# Step 800/3000
# Step 810/3000
# Step 820/3000
# Step 830/3000
# Step 840/3000
# Step 850/3000
# Step 860/3000
# Step 870/3000
# Step 880/3000
# Step 890/3000
# Step 900/3000
# Step 910/3000
# Step 920/3000
# Step 930/3000
# Step 940/3000
# Step 950/3000
# Step 960/3000
# Step 970/3000
# Step 980/3000
# Step 990/3000
# Step 1000/3000
# Step 1010/3000
# Step 1020/3000
# Step 1030/3000
# Step 1040/3000
# Step 1050/3000
# Step 1060/3000
# Step 1070/3000
# Step 1080/3000
# Step 1090/3000
# Step 1100/3000
# Step 1110/3000
# Step 1120/3000
# Step 1130/3000
# Step 1140/3000
# Step 1150/3000
# Step 1160/3000
# Step 1170/3000
# Step 1180/3000
# Step 1190/3000
# Step 1200/3000
# Step 1210/3000
# Step 1220/3000
# Step 1230/3000
# Step 1240/3000
# Step 1250/3000
# Step 1260/3000
# Step 1270/3000
# Step 1280/3000
# Step 1290/3000
# Step 1300/3000
# Step 1310/3000
# Step 1320/3000
# Step 1330/3000
# Step 1340/3000
# Step 1350/3000
# Step 1360/3000
# Step 1370/3000
# Step 1380/3000
# Step 1390/3000
# Step 1400/3000
# Step 1410/3000
# Step 1420/3000
# Step 1430/3000
# Step 1440/3000
# Step 1450/3000
# Step 1460/3000
# Step 1470/3000
# Step 1480/3000
# Step 1490/3000
# Step 1500/3000
# Step 1510/3000
# Step 1520/3000
# Step 1530/3000
# Step 1540/3000
# Step 1550/3000
# Step 1560/3000
# Step 1570/3000
# Step 1580/3000
# Step 1590/3000
# Step 1600/3000
# Step 1610/3000
# Step 1620/3000
# Step 1630/3000
# Step 1640/3000
# Step 1650/3000
# Step 1660/3000
# Step 1670/3000
# Step 1680/3000
# Step 1690/3000
# Step 1700/3000
# Step 1710/3000
# Step 1720/3000
# Step 1730/3000
# Step 1740/3000
# Step 1750/3000
# Step 1760/3000
# Step 1770/3000
# Step 1780/3000
# Step 1790/3000
# Step 1800/3000
# Step 1810/3000
# Step 1820/3000
# Step 1830/3000
# Step 1840/3000
# Step 1850/3000
# Step 1860/3000
# Step 1870/3000
# Step 1880/3000
# Step 1890/3000
# Step 1900/3000
# Step 1910/3000
# Step 1920/3000
# Step 1930/3000
# Step 1940/3000
# Step 1950/3000
# Step 1960/3000
# Step 1970/3000
# Step 1980/3000
# Step 1990/3000
# Step 2000/3000
# Step 2010/3000
# Step 2020/3000
# Step 2030/3000
# Step 2040/3000
# Step 2050/3000
# Step 2060/3000
# Step 2070/3000
# Step 2080/3000
# Step 2090/3000
# Step 2100/3000
# Step 2110/3000
# Step 2120/3000
# Step 2130/3000
# Step 2140/3000
# Step 2150/3000
# Step 2160/3000
# Step 2170/3000
# Step 2180/3000
# Step 2190/3000
# Step 2200/3000
# Step 2210/3000
# Step 2220/3000
# Step 2230/3000
# Step 2240/3000
# Step 2250/3000
# Step 2260/3000
# Step 2270/3000
# Step 2280/3000
# Step 2290/3000
# Step 2300/3000
# Step 2310/3000
# Step 2320/3000
# Step 2330/3000
# Step 2340/3000
# Step 2350/3000
# Step 2360/3000
# Step 2370/3000
# Step 2380/3000
# Step 2390/3000
# Step 2400/3000
# Step 2410/3000
# Step 2420/3000
# Step 2430/3000
# Step 2440/3000
# Step 2450/3000
# Step 2460/3000
# Step 2470/3000
# Step 2480/3000
# Step 2490/3000
# Step 2500/3000
# Step 2510/3000
# Step 2520/3000
# Step 2530/3000
# Step 2540/3000
# Step 2550/3000
# Step 2560/3000
# Step 2570/3000
# Step 2580/3000
# Step 2590/3000
# Step 2600/3000
# Step 2610/3000
# Step 2620/3000
# Step 2630/3000
# Step 2640/3000
# Step 2650/3000
# Step 2660/3000
# Step 2670/3000
# Step 2680/3000
# Step 2690/3000
# Step 2700/3000
# Step 2710/3000
# Step 2720/3000
# Step 2730/3000
# Step 2740/3000
# Step 2750/3000
# Step 2760/3000
# Step 2770/3000
# Step 2780/3000
# Step 2790/3000
# Step 2800/3000
# Step 2810/3000
# Step 2820/3000
# Step 2830/3000
# Step 2840/3000
# Step 2850/3000
# Step 2860/3000
# Step 2870/3000
# Step 2880/3000
# Step 2890/3000
# Step 2900/3000
# Step 2910/3000
# Step 2920/3000
# Step 2930/3000
# Step 2940/3000
# Step 2950/3000
# Step 2960/3000
# Step 2970/3000
# Step 2980/3000
# Step 2990/3000

# %%
fig, ax = plt.subplots(figsize=(10, 6))
for i in range(3, len(num_steps)):
    n_steps = num_steps[i]
    dt = total_evolve_time / n_steps
    total_avg_r = total_avg_r_conv[i]
    ax.plot(np.arange(n_steps) * dt * u.to_Gyr, jnp.array(total_avg_r) * u.to_Kpc, ls='--', label='Num Steps = %d' % n_steps)
ax.axhline(r_orbit * u.to_Kpc, color='red', ls=':', label='Initial Orbit Radius')
ax.set_ylabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
ax.set_xlabel(r"Gyr", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()


fig, ax = plt.subplots(figsize=(10, 6))


ax.plot(np.arange(num_steps[-1]) * dt * u.to_Gyr, jnp.array(total_avg_r) * u.to_Kpc, label='Average Radial Distance from Halo Center', ls='--')
#ax.plot(np.arange(num_steps) * dt * u.to_Gyr, jnp.array(r_values) * u.to_Kpc, label='Star Radial Distance from Halo Center', ls='-')
ax.axhline(r_orbit * u.to_Kpc, color='red', ls=':', label='Initial Orbit Radius')
ax.set_ylabel(r"$r \;\;\mathrm{[kpc]}$", fontsize = 15)
ax.set_xlabel(r"Gyr", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

fig, ax = plt.subplots()

stellar_v_disp = jnp.array(stellar_v_disp)


ax.plot(np.arange(num_steps[-1]) * dt * u.to_Gyr, stellar_v_disp * u.to_kms, label='Stellar Velocity Dispersion')
plt.yscale('log')
ax.set_ylabel(r"$\sigma_v \;\;\mathrm{[km/s]}$", fontsize = 15)
ax.set_xlabel(r"Gyr", fontsize = 15)
plt.legend(fontsize = 14)
plt.show()

# %%
importlib.reload(SSF)


total_evolve_time = 10 * u.from_Gyr
num_steps = 1000
dt = total_evolve_time / num_steps
num_steps = 300

r = jnp.logspace(jnp.log10(rmin), jnp.log10(rmax), 1000)

r_orbit = 0.19 * u.from_Kpc
init_pos = np.array([r_orbit, 0, 0]) #Starting as position (r_vir, 0, 0) = (x, y, z)

init_vel = np.sqrt(acc_mag * r_orbit) * np.array([0, 1, 0]) #Circular orbit velocity

eigen_energies = eigenstate_lib.radial_eigenmode_params.E  # shape (Nj,)
total_mass = wavefunction_params.total_mass
R_j_r = eval_library(r, eigenstate_lib.radial_eigenmode_params)
l = eigenstate_lib.radial_eigenmode_params.l

aj_2 = wavefunction_params.aj_2        # shape (Nj,)
rand_phase = jax.random.uniform(jax.random.PRNGKey(0), shape=aj_2.shape, minval=0.0, maxval=2 * jnp.pi,)
aj = np.sqrt(aj_2) * np.exp(1j * rand_phase)  # shape (Nj,)


ani = SSF.Make_animation_t_dep_3d(r_orbit, init_pos, init_vel, dt, num_steps, r, eigen_energies, l, R_j_r, aj, total_mass, Y_lms, Phi_psi)

HTML(ani.to_jshtml())
# Out:
# Frame:  0
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1005.74949982    -0.            -0.        ]
# [ 0.19001067 33.38788973  3.10508361]
# Time taken for potential calculation at r_orbit (s):  2.0461413860321045
# Frame:  0
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1026.89907801    -3.49149712     1.14817611]
# [ 0.19006453 33.38710814  6.24249469]
# Time taken for potential calculation at r_orbit (s):  2.1650149822235107
# Frame:  0
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1026.8756648     -3.49340482     1.11532773]
# [ 0.19020604 33.38477371  9.41132634]
# Time taken for potential calculation at r_orbit (s):  1.9165751934051514
# Frame:  0
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1027.08537958    -3.49484106     1.05692137]
# [ 0.1905174  33.38092904 12.60750397]
# Time taken for potential calculation at r_orbit (s):  2.26336932182312
# Frame:  1
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.02773170e+03 -3.49573980e+00  9.73488998e-01]
# [ 0.19106936 33.37566232 15.82423959]
# Time taken for potential calculation at r_orbit (s):  2.0571138858795166
# Frame:  2
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-431.18858135    0.43560569    1.09079264]
# [ 0.19309802 33.37001404 19.03264769]
# Time taken for potential calculation at r_orbit (s):  2.108423948287964
# Frame:  3
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-267.13774294   -1.14781729    0.67612726]
# [ 0.1980266  33.36477452 22.14197986]
# Time taken for potential calculation at r_orbit (s):  2.1845192909240723
# Frame:  4
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.54259915e+03 -4.16175477e+00 -1.09232837e+00]
# [ 0.2033689  33.35913378 25.10137261]
# Time taken for potential calculation at r_orbit (s):  1.9954357147216797
# Frame:  5
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.64582960e+03  2.30219349e+00 -4.50478962e-01]
# [ 0.20617234 33.35378374 27.98739181]
# Time taken for potential calculation at r_orbit (s):  2.1326658725738525
# Frame:  6
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-435.01166188    0.90831752   -0.64198038]
# [ 0.20859649 33.34975712 30.84628004]
# Time taken for potential calculation at r_orbit (s):  2.2492551803588867
# Frame:  7
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-6.90066264e+02  1.29045993e+00 -3.44502449e-01]
# [ 0.21245996 33.34693603 33.63165608]
# Time taken for potential calculation at r_orbit (s):  1.9485599994659424
# Frame:  8
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.42487680e+03 -5.64088861e-02 -1.91880811e-02]
# [ 0.21564271 33.34510725 36.34338474]
# Time taken for potential calculation at r_orbit (s):  2.128448247909546
# Frame:  9
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.85736552e+03 -4.62207285e+00  9.42660477e-02]
# [ 0.21575153 33.34305285 39.04957662]
# Time taken for potential calculation at r_orbit (s):  2.045509099960327
# Frame:  10
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-6.44143609e+02  1.27247053e+00 -2.35484829e-01]
# [ 0.21444509 33.34103781 41.81812194]
# Time taken for potential calculation at r_orbit (s):  1.8086740970611572
# Frame:  11
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.91409927e+03 -1.89145661e+00 -7.46743703e-01]
# [ 0.2117409  33.33967176 44.65617769]
# Time taken for potential calculation at r_orbit (s):  2.0719611644744873
# Frame:  12
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.61195790e+03  3.85878426e+00 -7.31711528e-01]
# [ 0.20598072 33.3395674  47.66444972]
# Time taken for potential calculation at r_orbit (s):  2.028881788253784
# Frame:  13
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-774.00520983   -1.28761049    1.96332101]
# [ 0.19990724 33.34108114 50.90132509]
# Time taken for potential calculation at r_orbit (s):  1.9783110618591309
# Frame:  14
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.71607961e+03  2.20572776e+00  8.83773002e-01]
# [ 0.19382633 33.34410538 54.36966016]
# Time taken for potential calculation at r_orbit (s):  2.073906660079956
# Frame:  15
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.17038253e+03  3.14380938e+00 -9.04502253e-02]
# [ 0.18760041 33.34991128 58.13216141]
# Time taken for potential calculation at r_orbit (s):  2.114102363586426
# Frame:  16
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-526.15166913    1.1392949     2.38072562]
# [ 0.18431077 33.35838426 62.1400892 ]
# Time taken for potential calculation at r_orbit (s):  2.0839850902557373
# Frame:  17
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1145.52673279     1.64497935    -4.27400005]
# [ 0.18444062 33.36877537 66.24024572]
# Time taken for potential calculation at r_orbit (s):  2.121405601501465
# Frame:  18
# Acceleration vector (a_r, a_theta, a_phi) at star position:  [-1.06898386e+03  2.18859105e-01 -2.28146048e+00]
# [  0.18704726  33.38027189 -63.22250484]
# Time taken for potential calculation at r_orbit (s):  2.1040596961975098
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 28
#      23 aj = np.sqrt(aj_2) * np.exp(1j * rand_phase)  # shape (Nj,)
#      26 ani = SSF.Make_animation_t_dep_3d(r_orbit, init_pos, init_vel, dt, num_steps, r, eigen_energies, l, R_j_r, aj, total_mass, Y_lms, Phi_psi)
# ---> 28 HTML(ani.to_jshtml())
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/matplotlib/animation.py:1376, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1372         path = Path(tmpdir, "temp.html")
#    1373         writer = HTMLWriter(fps=fps,
#    1374                             embed_frames=embed_frames,
#    1375                             default_mode=default_mode)
# -> 1376         self.save(str(path), writer=writer)
#    1377         self._html_representation = path.read_text()
#    1379 return self._html_representation
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/matplotlib/animation.py:1122, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1119 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1120     for anim, d in zip(all_anim, data):
#    1121         # TODO: See if turning off blit is really necessary
# -> 1122         anim._draw_next_frame(d, blit=False)
#    1123         if progress_callback is not None:
#    1124             progress_callback(frame_number, total_frames)
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/matplotlib/animation.py:1157, in Animation._draw_next_frame(self, framedata, blit)
#    1153 def _draw_next_frame(self, framedata, blit):
#    1154     # Breaks down the drawing of the next frame into steps of pre- and
#    1155     # post- draw, as well as the drawing of the frame itself.
#    1156     self._pre_draw(framedata, blit)
# -> 1157     self._draw_frame(framedata)
#    1158     self._post_draw(framedata, blit)
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/matplotlib/animation.py:1789, in FuncAnimation._draw_frame(self, framedata)
#    1785     self._save_seq = self._save_seq[-self._save_count:]
#    1787 # Call the func with framedata and args. If blitting is desired,
#    1788 # func needs to return a sequence of any artists that were modified.
# -> 1789 self._drawn_artists = self._func(framedata, *self._args)
#    1791 if self._blit:
#    1793     err = RuntimeError('The animation function must return a sequence '
#    1794                        'of Artist objects.')
#
# File ~/PhD_year_1/jaxsp/Adding_stellar_masses/Stellar_sim_funcs.py:1127, in Make_animation_t_dep_3d.<locals>.update(frame, dt, eigen_energies, l, aj, R_j_r, total_mass, r, dtheta, dphi, theta, phi, parent_j, Y_lm)
#    1119 acc_transposed = np.moveaxis(acc_vec, 0, -1)  # shape (3, 24, 47, 3)
#    1121 interp = RegularGridInterpolator(
#    1122     (r_vals, theta, phi),
#    1123     acc_transposed,
#    1124     method='linear'
#    1125 )
# -> 1127 acc_vec = interp(list(r_pos_sph))[0]
#    1129 r_mag = r_pos_sph[0]
#    1131 point.set_data([r_pos[0] * u.to_Kpc], [r_pos[1] * u.to_Kpc])
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:413, in RegularGridInterpolator.__call__(self, xi, method, nu)
#     407 if nu is not None and method not in self._SPLINE_METHODS_ndbspl:
#     408     raise ValueError(
#     409         f"Can only compute derivatives for methods "
#     410         f"{self._SPLINE_METHODS_ndbspl}, got {method =}."
#     411     )
# --> 413 xi, xi_shape, ndim, nans, out_of_bounds = self._prepare_xi(xi)
#     415 if method == "linear":
#     416     indices, norm_distances = self._find_indices(xi.T)
#
# File ~/anaconda3/envs/keirenv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:470, in RegularGridInterpolator._prepare_xi(self, xi)
#     467     for i, p in enumerate(xi.T):
#     468         if not np.logical_and(np.all(self.grid[i][0] <= p),
#     469                               np.all(p <= self.grid[i][-1])):
# --> 470             raise ValueError(
#     471                 f"One of the requested xi is out of bounds in dimension {i}"
#     472             )
#     473     out_of_bounds = None
#     474 else:
#
# ValueError: One of the requested xi is out of bounds in dimension 2
