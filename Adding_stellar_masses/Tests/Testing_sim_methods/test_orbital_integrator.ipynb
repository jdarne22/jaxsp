# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

#os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.95"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"



import Analytic_test as AT


import jax
jax.config.update("jax_enable_x64", True)
import numpy as np
import jax.numpy as jnp

import matplotlib.pyplot as plt

# %%
import importlib
importlib.reload(AT)


SphHT = True
integrator = 'leapfrog'
plot = False
dt_override = 20

frozen = True
static = True


l_band_size = 128
use_multi_gpu = True
sparse_k_batch=8192
r_chunk_size = 128
compute_dtype = jnp.complex128

L_out_frac = 1


sim = AT.StellarSimTDep(m22 = 1, r_half = 0.19, r_half_width = 0.05, no_of_particles = 5, no_time_steps = 1000, total_evolve_time = 10, r_min = 20, 
                            r_max_enclosing_frac = 0.99, no_radius_bins = 1000, SphHT = SphHT, integrator = integrator, frozen = frozen, static = static,
                            plot = plot, dt_override=dt_override, l_band_size=l_band_size, use_multi_gpu = use_multi_gpu,
                                sparse_k_batch=sparse_k_batch, r_chunk_size=r_chunk_size, compute_dtype=compute_dtype, L_out_frac=L_out_frac)
# Out:
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]
# [CudaDevice(id=0)]

# %%
sim.run_simulation()
# Out:
# Loading precomputed R_j_r from /home/joshua/PhD_year_1/jaxsp/Adding_stellar_masses/Tests/Testing_sim_methods/precomputed_wf/precomputed_R_j_r_m22_1_rbins_1000.npz...
# l max from jaxsp: 23
# Particle 0: v_circ = 3.420 km/s
# Particle 1: v_circ = 3.149 km/s
# Particle 2: v_circ = 3.425 km/s
# Particle 3: v_circ = 3.820 km/s
# Particle 4: v_circ = 3.189 km/s
# Mean r: 0.185 kpc
# Min T_orb: 333.391 Myr
# T_c: 1618.871 Myr
# dt: 0.017 Gyr
# Number of time steps: 599
# Total: 599 steps
# completed rho_lms precomputation
# Time step 1 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 2 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 3 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 4 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 5 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 6 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.27 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 7 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 8 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 9 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 10 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 11 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 12 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 13 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 14 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 15 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 16 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 17 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 18 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 19 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 20 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 21 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 22 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 23 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 24 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 25 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 26 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 27 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 28 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 29 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 30 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 31 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 32 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 33 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 34 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 35 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 36 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 37 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.30 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 38 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 39 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 40 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 41 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 42 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 43 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 44 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 45 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 46 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 47 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 48 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 49 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 50 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 51 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 52 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 53 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 54 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 55 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 56 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 57 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 58 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 59 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 60 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 61 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 62 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 63 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 64 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 65 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 66 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.22 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.10 seconds
# Time step 67 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.25 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 68 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 69 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 70 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 71 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 72 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 73 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 74 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 75 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 76 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 77 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 78 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 79 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 80 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 81 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 82 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 83 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 84 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 85 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 86 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 87 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 88 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 89 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 90 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 91 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 92 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 93 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 94 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 95 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 96 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.30 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 97 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 98 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 99 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 100 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 101 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 102 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 103 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 104 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 105 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 106 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 107 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 108 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 109 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 110 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 111 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 112 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 113 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 114 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 115 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 116 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 117 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 118 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 119 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 120 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 121 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 122 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 123 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 124 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 125 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.24 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.07 seconds
# Time step 126 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.20 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 127 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.04 seconds
# Time step 128 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 129 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 130 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 131 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 132 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 133 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 134 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 135 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 136 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 137 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 138 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 139 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 140 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 141 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 142 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 143 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 144 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 145 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 146 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 147 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 148 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 149 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 150 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 151 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 152 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 153 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 154 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 155 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 156 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 157 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 158 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 159 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 160 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 161 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 162 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 163 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 164 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 165 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 166 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 167 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 168 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 169 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 170 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 171 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 172 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 173 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 174 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 175 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 176 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 177 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 178 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 179 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 180 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 181 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 182 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 183 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 184 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 185 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 186 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 187 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 188 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 189 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 190 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 191 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 192 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 193 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 194 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 195 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 196 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 197 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 198 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 199 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 200 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 201 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 202 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 203 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 204 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 205 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 206 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 207 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 208 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 209 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 210 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 211 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 212 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 213 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 214 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 215 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 216 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 217 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 218 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 219 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 220 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 221 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 222 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 223 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 224 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 225 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 226 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 227 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 228 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 229 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 230 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 231 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 232 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 233 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 234 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 235 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 236 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 237 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 238 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 239 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 240 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 241 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 242 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 243 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 244 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 245 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 246 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 247 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 248 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 249 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 250 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 251 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 252 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 253 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 254 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 255 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 256 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 257 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 258 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 259 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 260 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 261 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 262 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 263 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 264 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 265 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 266 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 267 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 268 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 269 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 270 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 271 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 272 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 273 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 274 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 275 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 276 / 599
# ...
# Time stepping all particles completed in 0.03 seconds
# Time step 508 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 509 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 510 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 511 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 512 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 513 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 514 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 515 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 516 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 517 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 518 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 519 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 520 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 521 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 522 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 523 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 524 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 525 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 526 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 527 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 528 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 529 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 530 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 531 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 532 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 533 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 534 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 535 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 536 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 537 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.04 seconds
# Time step 538 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 539 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 540 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 541 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 542 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 543 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 544 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 545 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 546 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 547 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 548 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 549 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 550 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 551 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 552 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 553 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 554 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 555 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 556 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 557 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 558 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 559 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 560 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 561 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 562 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 563 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 564 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 565 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 566 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.04 seconds
# Time step 567 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 568 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 569 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 570 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 571 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 572 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 573 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 574 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 575 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 576 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 577 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 578 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 579 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 580 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 581 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 582 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 583 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 584 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 585 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 586 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 587 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 588 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 589 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.15 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 590 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 591 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 592 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 593 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 594 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 595 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 596 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 597 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 598 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds
# Time step 599 / 599
# Building rho_lms for this timestep...
# rho_lms built in 0.14 seconds
#   Force calls this timestep: 1
# Time stepping all particles completed in 0.03 seconds

# %%
positions_all = np.array([p.positions_xyz for p in sim.particles])  # (N_particles, N_steps+1, 3)
r_all         = np.array([p.r_values      for p in sim.particles])  # (N_particles, N_steps+1)
all_vels_cart = np.array([[np.array(v) for v in p.velocities_cart] for p in sim.particles])
kinetic_energy_all = np.array([p.kinetic_energy for p in sim.particles]) # (N_particles, N_steps+1)
potential_energy_all = np.array([p.potential_energy for p in sim.particles]) # (N_particles, N_steps+1)
ang_mom_all = np.array([p.ang_mom for p in sim.particles]) # (N_particles, N_steps+1, 3)

# %%
no_time_steps = sim.no_time_steps
# std across particles (axis=0) at each timestep → shape (n_timesteps,)
stellar_v_disp2 = np.sqrt(
    np.std(all_vels_cart[:, :, 0], axis=0)**2 +
    np.std(all_vels_cart[:, :, 1], axis=0)**2 +
    np.std(all_vels_cart[:, :, 2], axis=0)**2
)


x = np.arange(no_time_steps + 1)  # Time steps array


plt.plot(x * sim.dt * sim.u.to_Gyr, stellar_v_disp2 * sim.u.to_kms)
plt.xlabel('Time [Gyr]')
plt.ylabel('Stellar Velocity Dispersion [km/s]')
plt.title('Stellar Velocity Dispersion over Time')
plt.show()

R_half = np.mean(r_all, axis=0)  # (N_steps+1,) median across particles at each timestep

plt.plot(x * sim.dt * sim.u.to_Gyr, R_half * sim.u.to_Kpc, label='Average Particle Radius')
for particle in range(r_all.shape[0]-1):
    plt.plot(x * sim.dt * sim.u.to_Gyr, r_all[particle, :] * sim.u.to_Kpc, alpha = 0.2, color='gray')
plt.plot(x * sim.dt * sim.u.to_Gyr, r_all[-1, :] * sim.u.to_Kpc, alpha = 0.2, color='gray', label='Individual Particle Radii')
init_r_half = R_half[0] * sim.u.to_Kpc
plt.axhline(init_r_half, color='r', linestyle='--', label='Initial Mean Radius')
plt.xlabel('Time [Gyr]', fontsize=15)
plt.ylabel('Average Stellar Radius [Kpc]', fontsize=15)
plt.title('Average Stellar Radius over Time', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

# Timescale diagnostics
v0 = np.linalg.norm(all_vels_cart[:, 0, :], axis=1)
mean_T_orb = float(np.mean(2 * np.pi * r_all[:, 0] / v0) * sim.u.to_Gyr)

lambda_db_kpc = 19.15 / (sim.m22 * v0 * sim.u.to_kms)
T_c = lambda_db_kpc / (v0 * sim.u.to_Kpc) * sim.u.to_Gyr

#plt.axhline(np.mean(lambda_db_kpc), color='g', linestyle='--', label='$\\lambda_{{\\rm db}}$')


E = np.array(sim.eigen_energies)
freq_diff = np.abs(E[:, None] - E[None, :])
T_beat = (2 * np.pi / freq_diff) * sim.u.to_Gyr
min_T_beat = np.min(T_beat[np.isfinite(T_beat)])
max_T_beat = np.max(T_beat[np.isfinite(T_beat)])

dt_Gyr = sim.dt * sim.u.to_Gyr

info = (
    f"$T_{{\\rm orb}}$ (mean) = {mean_T_orb:.3f} Gyr\n"
    f"$T_{{\\rm c}}$ = {float(np.mean(T_c)):.3f} Gyr\n"
    f"Beat time band: [{min_T_beat:.3f}, {max_T_beat:.3f}] Gyr\n"
    f"$\\Delta t$ = {dt_Gyr:.4f} Gyr"
)

plt.text(1.02, 0.98, info, transform=plt.gca().transAxes,
         verticalalignment='top', fontsize=14,
         bbox=dict(boxstyle='round', facecolor='paleturquoise', alpha=0.6))

plt.legend(bbox_to_anchor=(1.65, 0.7), fontsize=14)
plt.show()


fig, ax = plt.subplots(1, 2, figsize=(12, 5))

for particle in range(ang_mom_all.shape[0]):
    ax[0].plot(x * sim.dt * sim.u.to_Gyr, (kinetic_energy_all[particle] + potential_energy_all[particle]), label='Total Energy')
ax[0].set_xlabel('Time [Gyr]')
ax[0].set_ylabel('Total Energy [J]')
ax[0].set_title('Total Energy over Time')




for particle in range(ang_mom_all.shape[0]):
    ax[1].plot(x * sim.dt * sim.u.to_Gyr, ang_mom_all[particle], label='Total angular momentum')
ax[1].set_xlabel('Time [Gyr]')
ax[1].set_ylabel('Total angular momentum [kg m^2/s]')
ax[1].set_title('Total angular momentum over Time')


plt.tight_layout()
plt.show()
